# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#하이퍼파라미터-세팅-및-seed-고정" data-toc-modified-id="하이퍼파라미터-세팅-및-seed-고정-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>하이퍼파라미터 세팅 및 seed 고정</a></span></li><li><span><a href="#학습-데이터-EDA" data-toc-modified-id="학습-데이터-EDA-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>학습 데이터 EDA</a></span></li><li><span><a href="#데이터-전처리-함수-정의-(Dataset)" data-toc-modified-id="데이터-전처리-함수-정의-(Dataset)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>데이터 전처리 함수 정의 (Dataset)</a></span></li><li><span><a href="#Dataset-정의-및-DataLoader-할당" data-toc-modified-id="Dataset-정의-및-DataLoader-할당-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Dataset 정의 및 DataLoader 할당</a></span><ul class="toc-item"><li><span><a href="#데이터-샘플-시각화-(Show-example-image-and-mask)" data-toc-modified-id="데이터-샘플-시각화-(Show-example-image-and-mask)-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>데이터 샘플 시각화 (Show example image and mask)</a></span></li></ul></li><li><span><a href="#baseline-model" data-toc-modified-id="baseline-model-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>baseline model</a></span><ul class="toc-item"><li><span><a href="#smp.Unet()" data-toc-modified-id="smp.Unet()-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span><code>smp.Unet()</code></a></span></li></ul></li><li><span><a href="#train,-validation,-test-함수-정의" data-toc-modified-id="train,-validation,-test-함수-정의-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>train, validation, test 함수 정의</a></span></li><li><span><a href="#모델-저장-함수-정의" data-toc-modified-id="모델-저장-함수-정의-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>모델 저장 함수 정의</a></span></li><li><span><a href="#모델-생성-및-Loss-function,-Optimizer-정의" data-toc-modified-id="모델-생성-및-Loss-function,-Optimizer-정의-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>모델 생성 및 Loss function, Optimizer 정의</a></span></li><li><span><a href="#저장된-model-불러오기-(학습된-이후)" data-toc-modified-id="저장된-model-불러오기-(학습된-이후)-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>저장된 model 불러오기 (학습된 이후)</a></span><ul class="toc-item"><li><span><a href="#plot_examples()-시각화-함수-정의" data-toc-modified-id="plot_examples()-시각화-함수-정의-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span><code>plot_examples()</code> 시각화 함수 정의</a></span><ul class="toc-item"><li><span><a href="#train-set-시각화" data-toc-modified-id="train-set-시각화-9.1.1"><span class="toc-item-num">9.1.1&nbsp;&nbsp;</span>train set 시각화</a></span></li><li><span><a href="#validation-set-시각화" data-toc-modified-id="validation-set-시각화-9.1.2"><span class="toc-item-num">9.1.2&nbsp;&nbsp;</span>validation set 시각화</a></span></li><li><span><a href="#test-set-시각화" data-toc-modified-id="test-set-시각화-9.1.3"><span class="toc-item-num">9.1.3&nbsp;&nbsp;</span>test set 시각화</a></span></li></ul></li></ul></li><li><span><a href="#submission을-위한-test-함수-정의" data-toc-modified-id="submission을-위한-test-함수-정의-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>submission을 위한 test 함수 정의</a></span></li><li><span><a href="#submission.csv-생성" data-toc-modified-id="submission.csv-생성-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>submission.csv 생성</a></span></li></ul></div>

# %%
import os
import random
import time
import json
import warnings 
warnings.filterwarnings('ignore')

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from utils import label_accuracy_score, add_hist
import cv2
import wandb
import datetime

import numpy as np
import pandas as pd
from tqdm import tqdm

# 전처리를 위한 라이브러리
from pycocotools.coco import COCO
import torchvision
import torchvision.transforms as transforms

#!pip install albumentations==0.4.6
import albumentations as A
from albumentations.pytorch import ToTensorV2

# 시각화를 위한 라이브러리
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from matplotlib.patches import Patch

#!pip install webcolors
import webcolors

plt.rcParams['axes.grid'] = False

print('pytorch version: {}'.format(torch.__version__))
print('GPU 사용 가능 여부: {}'.format(torch.cuda.is_available()))

print(torch.cuda.get_device_name(0))
print(torch.cuda.device_count())

# GPU 사용 가능 여부에 따라 device 정보 저장
device = "cuda" if torch.cuda.is_available() else "cpu"
# Out:
# pytorch version: 1.7.1
# GPU 사용 가능 여부: True
# Tesla V100-PCIE-32GB
# 1

# %% [markdown]
# ## 하이퍼파라미터 세팅 및 seed 고정

# %%
batch_size = 8   # Mini-batch size
num_epochs = 70
learning_rate = 0.0001

# %%
# seed 고정
random_seed = 21
torch.manual_seed(random_seed)
torch.cuda.manual_seed(random_seed)
torch.cuda.manual_seed_all(random_seed) # if use multi-GPU
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(random_seed)
random.seed(random_seed)

# %% [markdown]
# ## 학습 데이터 EDA

# %%
# %matplotlib inline

dataset_path  = '../data'
anns_file_path = dataset_path + '/' + 'train_all.json'

# Read annotations
with open(anns_file_path, 'r') as f:
    dataset = json.loads(f.read())

categories = dataset['categories']
anns = dataset['annotations']
imgs = dataset['images']
nr_cats = len(categories)
nr_annotations = len(anns)
nr_images = len(imgs)

# Load categories and super categories
cat_names = []
super_cat_names = []
super_cat_ids = {}
super_cat_last_name = ''
nr_super_cats = 0
for cat_it in categories:
    cat_names.append(cat_it['name'])
    super_cat_name = cat_it['supercategory']
    # Adding new supercat
    if super_cat_name != super_cat_last_name:
        super_cat_names.append(super_cat_name)
        super_cat_ids[super_cat_name] = nr_super_cats
        super_cat_last_name = super_cat_name
        nr_super_cats += 1

print('Number of super categories:', nr_super_cats)
print('Number of categories:', nr_cats)
print('Number of annotations:', nr_annotations)
print('Number of images:', nr_images)
# Out:
# Number of super categories: 10
# Number of categories: 10
# Number of annotations: 26240
# Number of images: 3272

# %%
# Count annotations
cat_histogram = np.zeros(nr_cats,dtype=int)
for ann in anns:
    cat_histogram[ann['category_id']-1] += 1

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(5,5))

# Convert to DataFrame
df = pd.DataFrame({'Categories': cat_names, 'Number of annotations': cat_histogram})
df = df.sort_values('Number of annotations', 0, False)

# Plot the histogram
plt.title("category distribution of train_all set ")
plot_1 = sns.barplot(x="Number of annotations", y="Categories", data=df, label="Total", color="b")

# %%
# category labeling 
sorted_temp_df = df.sort_index()

# background = 0 에 해당되는 label 추가 후 기존들을 모두 label + 1 로 설정
sorted_df = pd.DataFrame(["Backgroud"], columns = ["Categories"])
sorted_df = sorted_df.append(sorted_temp_df, ignore_index=True)

# %%
# class (Categories) 에 따른 index 확인 (0~10 : 총 11개)
sorted_df
# Out:
#        Categories  Number of annotations
# 0       Backgroud                    NaN
# 1   General trash                 2782.0
# 2           Paper                 9311.0
# 3      Paper pack                  659.0
# 4           Metal                  562.0
# 5           Glass                  610.0
# 6         Plastic                 3090.0
# 7       Styrofoam                 1343.0
# 8     Plastic bag                 7643.0
# 9         Battery                   63.0
# 10       Clothing                  177.0

# %% [markdown]
# ## 데이터 전처리 함수 정의 (Dataset)

# %%
category_names = list(sorted_df.Categories)

def get_classname(classID, cats):
    for i in range(len(cats)):
        if cats[i]['id']==classID:
            return cats[i]['name']
    return "None"

class CustomDataLoader(Dataset):
    """COCO format"""
    def __init__(self, data_dir, mode = 'train', transform = None):
        super().__init__()
        self.mode = mode
        self.transform = transform
        self.coco = COCO(data_dir)
        
    def __getitem__(self, index: int):
        # dataset이 index되어 list처럼 동작
        image_id = self.coco.getImgIds(imgIds=index)
        image_infos = self.coco.loadImgs(image_id)[0]
        
        # cv2 를 활용하여 image 불러오기
        images = cv2.imread(os.path.join(dataset_path, image_infos['file_name']))
        images = cv2.cvtColor(images, cv2.COLOR_BGR2RGB).astype(np.float32)
        images /= 255.0
        
        if (self.mode in ('train', 'val')):
            ann_ids = self.coco.getAnnIds(imgIds=image_infos['id'])
            anns = self.coco.loadAnns(ann_ids)

            # Load the categories in a variable
            cat_ids = self.coco.getCatIds()
            cats = self.coco.loadCats(cat_ids)

            # masks : size가 (height x width)인 2D
            # 각각의 pixel 값에는 "category id" 할당
            # Background = 0
            masks = np.zeros((image_infos["height"], image_infos["width"]))
            # General trash = 1, ... , Cigarette = 10
            anns = sorted(anns, key=lambda idx : idx['area'], reverse=True)
            for i in range(len(anns)):
                className = get_classname(anns[i]['category_id'], cats)
                pixel_value = category_names.index(className)
                masks[self.coco.annToMask(anns[i]) == 1] = pixel_value
            masks = masks.astype(np.int8)
                        
            # transform -> albumentations 라이브러리 활용
            if self.transform is not None:
                transformed = self.transform(image=images, mask=masks)
                images = transformed["image"]
                masks = transformed["mask"]
            return images, masks, image_infos
        
        if self.mode == 'test':
            # transform -> albumentations 라이브러리 활용
            if self.transform is not None:
                transformed = self.transform(image=images)
                images = transformed["image"]
            return images, image_infos
    
    def __len__(self) -> int:
        # 전체 dataset의 size를 return
        return len(self.coco.getImgIds())

# %% [markdown]
# ## Dataset 정의 및 DataLoader 할당

# %%
# train.json / validation.json / test.json 디렉토리 설정
train_path = dataset_path + '/init_train_MultiStfKFold.json'
val_path = dataset_path + '/init_val_MultiStfKFold.json'
test_path = dataset_path + '/test.json'

# collate_fn needs for batch
def collate_fn(batch):
    return tuple(zip(*batch))


import albumentations as A
from albumentations.pytorch import ToTensorV2

train_transform = A.Compose([
                            A.OneOf(
                                [
                                    A.HorizontalFlip(),
                                    A.VerticalFlip()
                                ],
                                p=0.5
                            ),
                             A.OneOf(
                                [
                                    A.RandomRotate90(),
                                    A.ShiftScaleRotate(rotate_method='largest_box', p=0.75)
                                ],
                                p=0.5
                            ),
                            A.OneOf(
                                [
                                    A.RandomContrast(),
                                    A.RandomBrightness(p=0.7)
                                ],
                                p=0.5
                            ),
                            A.ElasticTransform(p=0.25),
                            A.OneOf(
                                [
                                    A.GaussianBlur(),
                                    A.ColorJitter()
                                ],
                                p=0.5
                            ),
                            A.OneOf(
                                [
                                    A.RandomRain(),
                                    A.RandomShadow(p=0.6),
                                    A.RandomSnow(p=0.7)
                                ],
                                p=0.5
                            ),
                            # A.GridDropout(ratio=0.33,unit_size_min=50,unit_size_max=100, random_offset=True, p=0.5),
                            # A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0, always_apply=False, p=1.0),
                            ToTensorV2()
                            ])

val_transform = A.Compose([
                            
                            # A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0, always_apply=False, p=1.0),
                            ToTensorV2()
                          ])

test_transform = A.Compose([
                            # A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0, always_apply=False, p=1.0),
                            ToTensorV2()
                           ])

# create own Dataset 1 (skip)
# validation set을 직접 나누고 싶은 경우
# random_split 사용하여 data set을 8:2 로 분할
# train_size = int(0.8*len(dataset))
# val_size = int(len(dataset)-train_size)
# dataset = CustomDataLoader(data_dir=train_path, mode='train', transform=transform)
# train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

# create own Dataset 2
# train dataset
train_dataset = CustomDataLoader(data_dir=train_path, mode='train', transform=train_transform)

# validation dataset
val_dataset = CustomDataLoader(data_dir=val_path, mode='val', transform=val_transform)

# test dataset
test_dataset = CustomDataLoader(data_dir=test_path, mode='test', transform=test_transform)


# DataLoader
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size,
                                           shuffle=True,
                                           num_workers=4,
                                           collate_fn=collate_fn)

val_loader = torch.utils.data.DataLoader(dataset=val_dataset, 
                                         batch_size=batch_size,
                                         shuffle=False,
                                         num_workers=4,
                                         collate_fn=collate_fn)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          num_workers=4,
                                          collate_fn=collate_fn)
# Out:
# loading annotations into memory...
# Done (t=2.57s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=1.34s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!

# %% [markdown]
# ### 데이터 샘플 시각화 (Show example image and mask)
#
# - `train_loader`
# - `val_loader`
# - `test_loader`

# %%
class_colormap = pd.read_csv("class_dict.csv")
class_colormap
# Out:
#              name    r    g    b
# 0       Backgroud    0    0    0
# 1   General trash  192    0  128
# 2           Paper    0  128  192
# 3      Paper pack    0  128   64
# 4           Metal  128    0    0
# 5           Glass   64    0  128
# 6         Plastic   64    0  192
# 7       Styrofoam  192  128   64
# 8     Plastic bag  192  192  128
# 9         Battery   64   64  128
# 10       Clothing  128    0  192

# %%
def create_trash_label_colormap():
    """Creates a label colormap used in Trash segmentation.
    Returns:
        A colormap for visualizing segmentation results.
    """
    colormap = np.zeros((11, 3), dtype=np.uint8)
    for inex, (_, r, g, b) in enumerate(class_colormap.values):
        colormap[inex] = [r, g, b]
    
    return colormap

def label_to_color_image(label):
    """Adds color defined by the dataset colormap to the label.

    Args:
        label: A 2D array with integer type, storing the segmentation label.

    Returns:
        result: A 2D array with floating type. The element of the array
                is the color indexed by the corresponding element in the input label
                to the trash color map.

    Raises:
        ValueError: If label is not of rank 2 or its value is larger than color
              map maximum entry.
    """
    if label.ndim != 2:
        raise ValueError('Expect 2-D input label')

    colormap = create_trash_label_colormap()

    if np.max(label) >= len(colormap):
        raise ValueError('label value too large.')

    return colormap[label]

# %%
# train_loader의 output 결과(image 및 mask) 확인
for imgs, masks, image_infos in train_loader:
    image_infos = image_infos[0]
    temp_images = imgs
    temp_masks = masks
    break

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 12))

print('image shape:', list(temp_images[0].shape))
print('mask shape: ', list(temp_masks[0].shape))
print('Unique values, category of transformed mask : \n', [{int(i),category_names[int(i)]} for i in list(np.unique(temp_masks[0]))])


ax1.imshow(temp_images[0].permute([1,2,0])) # normalize 했기에 이미지 이상하게 나옴
ax1.grid(False)
ax1.set_title("input image : {}".format(image_infos['file_name']), fontsize = 15)

ax2.imshow(temp_masks[0])
ax2.grid(False)
ax2.set_title("masks : {}".format(image_infos['file_name']), fontsize = 15)

plt.show()
# Out:
# image shape: [3, 512, 512]
# mask shape:  [512, 512]
# Unique values, category of transformed mask :
#  [{0, 'Backgroud'}, {'General trash', 1}, {2, 'Paper'}, {4, 'Metal'}, {'Plastic', 6}, {8, 'Plastic bag'}]

# %%
# val_loader의 output 결과(image 및 mask) 확인
for imgs, masks, image_infos in val_loader:
    image_infos = image_infos[0]
    temp_images = imgs
    temp_masks = masks
    
    break

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 12))

print('image shape:', list(temp_images[0].shape))
print('mask shape: ', list(temp_masks[0].shape))

print('Unique values, category of transformed mask : \n', [{int(i),category_names[int(i)]} for i in list(np.unique(temp_masks[0]))])

ax1.imshow(temp_images[0].permute([1,2,0]))
ax1.grid(False)
ax1.set_title("input image : {}".format(image_infos['file_name']), fontsize = 15)

ax2.imshow(temp_masks[0])
ax2.grid(False)
ax2.set_title("masks : {}".format(image_infos['file_name']), fontsize = 15)

plt.show()
# Out:
# image shape: [3, 512, 512]
# mask shape:  [512, 512]
# Unique values, category of transformed mask :
#  [{0, 'Backgroud'}, {2, 'Paper'}, {'Plastic', 6}]

# %%
# test_loader의 output 결과(image) 확인
for imgs, image_infos in test_loader:
    image_infos = image_infos[0]
    temp_images = imgs
    
    break

fig, ax1 = plt.subplots(nrows=1, ncols=1, figsize=(6, 6))

print('image shape:', list(temp_images[0].shape))

ax1.imshow(temp_images[0].permute([1,2,0]))
ax1.grid(False)
ax1.set_title("input image : {}".format(image_infos['file_name']), fontsize = 15)

plt.show()
# Out:
# image shape: [3, 512, 512]

# %% [markdown]
# ## baseline model
#
# ### `smp.Unet()`

# %%
# jupyter command 에서 library download 하기
# !pip install git+https://github.com/qubvel/segmentation_models.pytorch

import segmentation_models_pytorch as smp

# model 불러오기
# 출력 label 수 정의 (classes=11)
model = smp.Unet(
    encoder_name="efficientnet-b0", # choose encoder, e.g. mobilenet_v2 or efficientnet-b7
    encoder_weights="imagenet",     # use `imagenet` pre-trained weights for encoder initialization
    in_channels=3,                  # model input channels (1 for gray-scale images, 3 for RGB, etc.)
    classes=11,                     # model output channels (number of classes in your dataset)
)

# %%
# 구현된 model에 임의의 input을 넣어 output이 잘 나오는지 test
x = torch.randn([2, 3, 512, 512])
print(f"input shape : {x.shape}")
out = model(x)
print(f"output shape : {out.size()}")
# Out:
# input shape : torch.Size([2, 3, 512, 512])
# output shape : torch.Size([2, 11, 512, 512])

# %% [markdown]
# ## train, validation, test 함수 정의

# %%
def train(num_epochs, model, data_loader, val_loader, criterion, optimizer, saved_dir, val_every, device,learning_rate,batch_size):
    now = (datetime.datetime.now().replace(microsecond=0) + datetime.timedelta(hours=9)).strftime("%m-%d %H:%M")
    wandb.init(project="trash_segmentation", entity="aidatapkt", name = f'all-griddropout{now}')
    wandb.config = {
        "epoch" : num_epochs,
        "lr" : learning_rate,
        "batch_size": batch_size
                        }
    print(f'Start training..')
    n_class = 11
    best_loss = 9999999
    best_mIoU = 0
    
    for epoch in range(num_epochs):
        model.train()

        hist = np.zeros((n_class, n_class))
        for step, (images, masks, _) in enumerate(data_loader):
            images = torch.stack(images)       
            masks = torch.stack(masks).long() 
            
            # gpu 연산을 위해 device 할당
            images, masks = images.to(device), masks.to(device)
            
            # device 할당
            model = model.to(device)
            
            # inference
            outputs = model(images)
            
            # loss 계산 (cross entropy loss)
            loss = criterion(outputs, masks)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            outputs = torch.argmax(outputs, dim=1).detach().cpu().numpy()
            masks = masks.detach().cpu().numpy()
            
            hist = add_hist(hist, masks, outputs, n_class=n_class)
            acc, acc_cls, mIoU, fwavacc, IoU = label_accuracy_score(hist)
            
            # step 주기에 따른 loss 출력
            if (step + 1) % 25 == 0:
                print(f'Epoch [{epoch+1}/{num_epochs}], Step [{step+1}/{len(train_loader)}], \
                        Loss: {round(loss.item(),4)}, mIoU: {round(mIoU,4)}')
             
        # validation 주기에 따른 loss 출력 및 best model 저장
        if (epoch + 1) % val_every == 0:
            avrg_loss, val_mIoU = validation(epoch + 1, model, val_loader, criterion, device)
            if val_mIoU > best_mIoU:
                print(f"Best performance at epoch: {epoch + 1}")
                print(f"Save model in {saved_dir}")
                print(f"best model's epoch is {epoch+1}")
                best_mIoU = val_mIoU
                save_model(model, saved_dir)

# %%
def validation(epoch, model, data_loader, criterion, device):
    print(f'Start validation #{epoch}')
    model.eval()

    with torch.no_grad():
        n_class = 11
        total_loss = 0
        cnt = 0
        
        hist = np.zeros((n_class, n_class))
        for step, (images, masks, _) in enumerate(data_loader):
            
            images = torch.stack(images)       
            masks = torch.stack(masks).long()  

            images, masks = images.to(device), masks.to(device)            
            
            # device 할당
            model = model.to(device)
            
            outputs = model(images)
            loss = criterion(outputs, masks)
            total_loss += loss
            cnt += 1
            
            outputs = torch.argmax(outputs, dim=1).detach().cpu().numpy()
            masks = masks.detach().cpu().numpy()
            
            hist = add_hist(hist, masks, outputs, n_class=n_class)
        
        acc, acc_cls, mIoU, fwavacc, IoU = label_accuracy_score(hist)
        IoU_by_class = [{classes : round(IoU,4)} for IoU, classes in zip(IoU , sorted_df['Categories'])]
        
        avrg_loss = total_loss / cnt
        print(f'Validation #{epoch}  Average Loss: {round(avrg_loss.item(), 4)}, Accuracy : {round(acc, 4)}, \
                mIoU: {round(mIoU, 4)}')
        print(f'IoU by class : {IoU_by_class}')
        
        wandb.log({
            'val mIoU' : round(mIoU, 4),
            'val loss' : round(avrg_loss.item(), 4),
            'epoch' : epoch
        })
    return avrg_loss, mIoU

# %% [markdown]
# ## 모델 저장 함수 정의

# %%
# 모델 저장 함수 정의
val_every = 1

saved_dir = './saved'
if not os.path.isdir(saved_dir):                                                           
    os.mkdir(saved_dir)

def save_model(model, saved_dir, file_name='augall-griddropout_efficient_unet_best_model.pt'):
    check_point = {'net': model.state_dict()}
    output_path = os.path.join(saved_dir, file_name)
    torch.save(model, output_path)

# %% [markdown]
# ## 모델 생성 및 Loss function, Optimizer 정의

# %%
# Loss function 정의
criterion = nn.CrossEntropyLoss()

# Optimizer 정의
optimizer = torch.optim.Adam(params = model.parameters(), lr = learning_rate, weight_decay=1e-6)

# %%
train(num_epochs, model, train_loader, val_loader, criterion, optimizer, saved_dir, val_every, device,learning_rate,batch_size)
# Out:
# wandb: Currently logged in as: aidatapkt. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.7
# Run data is saved locally in <code>/opt/ml/input/code/wandb/run-20230101_222906-25hucpu5</code>
# Syncing run <strong><a href="https://wandb.ai/aidatapkt/trash_segmentation/runs/25hucpu5" target="_blank">all-griddropout01-02 07:29</a></strong> to <a href="https://wandb.ai/aidatapkt/trash_segmentation" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Start training..
# Epoch [1/70], Step [25/328],                         Loss: 2.085, mIoU: 0.0393
# Epoch [1/70], Step [50/328],                         Loss: 1.9052, mIoU: 0.0597
# Epoch [1/70], Step [75/328],                         Loss: 1.7223, mIoU: 0.0755
# Epoch [1/70], Step [100/328],                         Loss: 1.4941, mIoU: 0.0901
# Epoch [1/70], Step [125/328],                         Loss: 1.2262, mIoU: 0.1027
# Epoch [1/70], Step [150/328],                         Loss: 1.1224, mIoU: 0.1107
# Epoch [1/70], Step [175/328],                         Loss: 1.0715, mIoU: 0.1167
# Epoch [1/70], Step [200/328],                         Loss: 1.0551, mIoU: 0.1224
# Epoch [1/70], Step [225/328],                         Loss: 1.0042, mIoU: 0.1272
# Epoch [1/70], Step [250/328],                         Loss: 0.7976, mIoU: 0.1307
# Epoch [1/70], Step [275/328],                         Loss: 0.6758, mIoU: 0.1334
# Epoch [1/70], Step [300/328],                         Loss: 0.5927, mIoU: 0.1369
# Epoch [1/70], Step [325/328],                         Loss: 0.495, mIoU: 0.1397
# Start validation #1
# Validation #1  Average Loss: 0.6258, Accuracy : 0.8511,                 mIoU: 0.1861
# IoU by class : [{'Backgroud': 0.9185}, {'General trash': 0.0}, {'Paper': 0.4901}, {'Paper pack': 0.0}, {'Metal': 0.0}, {'Glass': 0.0}, {'Plastic': 0.0}, {'Styrofoam': 0.0}, {'Plastic bag': 0.6383}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 1
# Save model in ./saved
# best model's epoch is 1
# Epoch [2/70], Step [25/328],                         Loss: 0.5621, mIoU: 0.1705
# Epoch [2/70], Step [50/328],                         Loss: 0.6872, mIoU: 0.164
# Epoch [2/70], Step [75/328],                         Loss: 0.6116, mIoU: 0.1669
# Epoch [2/70], Step [100/328],                         Loss: 0.9734, mIoU: 0.1672
# Epoch [2/70], Step [125/328],                         Loss: 0.6468, mIoU: 0.1682
# Epoch [2/70], Step [150/328],                         Loss: 0.6832, mIoU: 0.1697
# Epoch [2/70], Step [175/328],                         Loss: 0.6963, mIoU: 0.1697
# Epoch [2/70], Step [200/328],                         Loss: 0.6959, mIoU: 0.1707
# Epoch [2/70], Step [225/328],                         Loss: 0.545, mIoU: 0.1705
# Epoch [2/70], Step [250/328],                         Loss: 0.7775, mIoU: 0.1706
# Epoch [2/70], Step [275/328],                         Loss: 0.7262, mIoU: 0.1711
# Epoch [2/70], Step [300/328],                         Loss: 0.5237, mIoU: 0.1718
# Epoch [2/70], Step [325/328],                         Loss: 0.4967, mIoU: 0.172
# Start validation #2
# Validation #2  Average Loss: 0.5223, Accuracy : 0.8566,                 mIoU: 0.1884
# IoU by class : [{'Backgroud': 0.9288}, {'General trash': 0.0}, {'Paper': 0.5519}, {'Paper pack': 0.0}, {'Metal': 0.0}, {'Glass': 0.0}, {'Plastic': 0.0}, {'Styrofoam': 0.0}, {'Plastic bag': 0.5916}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 2
# Save model in ./saved
# best model's epoch is 2
# Epoch [3/70], Step [25/328],                         Loss: 0.8332, mIoU: 0.1739
# Epoch [3/70], Step [50/328],                         Loss: 0.5773, mIoU: 0.1731
# Epoch [3/70], Step [75/328],                         Loss: 0.4456, mIoU: 0.175
# Epoch [3/70], Step [100/328],                         Loss: 0.5478, mIoU: 0.1745
# Epoch [3/70], Step [125/328],                         Loss: 0.5785, mIoU: 0.1746
# Epoch [3/70], Step [150/328],                         Loss: 0.57, mIoU: 0.1744
# Epoch [3/70], Step [175/328],                         Loss: 0.4226, mIoU: 0.1762
# Epoch [3/70], Step [200/328],                         Loss: 0.7024, mIoU: 0.1772
# Epoch [3/70], Step [225/328],                         Loss: 0.4164, mIoU: 0.1777
# Epoch [3/70], Step [250/328],                         Loss: 1.1693, mIoU: 0.177
# Epoch [3/70], Step [275/328],                         Loss: 0.4744, mIoU: 0.1771
# Epoch [3/70], Step [300/328],                         Loss: 0.7935, mIoU: 0.1771
# Epoch [3/70], Step [325/328],                         Loss: 0.6767, mIoU: 0.177
# Start validation #3
# Validation #3  Average Loss: 0.4873, Accuracy : 0.8606,                 mIoU: 0.1915
# IoU by class : [{'Backgroud': 0.9188}, {'General trash': 0.0}, {'Paper': 0.5176}, {'Paper pack': 0.0}, {'Metal': 0.0}, {'Glass': 0.0}, {'Plastic': 0.0}, {'Styrofoam': 0.0}, {'Plastic bag': 0.6703}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 3
# Save model in ./saved
# best model's epoch is 3
# Epoch [4/70], Step [25/328],                         Loss: 0.9735, mIoU: 0.1966
# Epoch [4/70], Step [50/328],                         Loss: 0.6766, mIoU: 0.1819
# Epoch [4/70], Step [75/328],                         Loss: 0.5572, mIoU: 0.1795
# Epoch [4/70], Step [100/328],                         Loss: 0.4639, mIoU: 0.1812
# Epoch [4/70], Step [125/328],                         Loss: 0.4071, mIoU: 0.1807
# Epoch [4/70], Step [150/328],                         Loss: 0.69, mIoU: 0.1811
# Epoch [4/70], Step [175/328],                         Loss: 0.7408, mIoU: 0.1806
# Epoch [4/70], Step [200/328],                         Loss: 0.6168, mIoU: 0.181
# Epoch [4/70], Step [225/328],                         Loss: 0.875, mIoU: 0.181
# Epoch [4/70], Step [250/328],                         Loss: 0.3021, mIoU: 0.1811
# Epoch [4/70], Step [275/328],                         Loss: 0.4814, mIoU: 0.1832
# Epoch [4/70], Step [300/328],                         Loss: 0.5518, mIoU: 0.1836
# Epoch [4/70], Step [325/328],                         Loss: 0.2925, mIoU: 0.1848
# Start validation #4
# Validation #4  Average Loss: 0.4517, Accuracy : 0.8677,                 mIoU: 0.2124
# IoU by class : [{'Backgroud': 0.9334}, {'General trash': 0.0}, {'Paper': 0.5588}, {'Paper pack': 0.0}, {'Metal': 0.0}, {'Glass': 0.0}, {'Plastic': 0.1607}, {'Styrofoam': 0.0}, {'Plastic bag': 0.6834}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 4
# Save model in ./saved
# best model's epoch is 4
# Epoch [5/70], Step [25/328],                         Loss: 0.3206, mIoU: 0.2241
# Epoch [5/70], Step [50/328],                         Loss: 0.7048, mIoU: 0.1963
# Epoch [5/70], Step [75/328],                         Loss: 0.7006, mIoU: 0.197
# Epoch [5/70], Step [100/328],                         Loss: 0.6591, mIoU: 0.1975
# Epoch [5/70], Step [125/328],                         Loss: 0.5507, mIoU: 0.1975
# Epoch [5/70], Step [150/328],                         Loss: 0.9276, mIoU: 0.1979
# Epoch [5/70], Step [175/328],                         Loss: 0.3045, mIoU: 0.1989
# Epoch [5/70], Step [200/328],                         Loss: 0.4559, mIoU: 0.1978
# Epoch [5/70], Step [225/328],                         Loss: 0.6438, mIoU: 0.1979
# Epoch [5/70], Step [250/328],                         Loss: 0.4215, mIoU: 0.1986
# Epoch [5/70], Step [275/328],                         Loss: 0.2769, mIoU: 0.1994
# Epoch [5/70], Step [300/328],                         Loss: 0.9023, mIoU: 0.1997
# Epoch [5/70], Step [325/328],                         Loss: 0.2355, mIoU: 0.2004
# Start validation #5
# Validation #5  Average Loss: 0.4409, Accuracy : 0.8671,                 mIoU: 0.2135
# IoU by class : [{'Backgroud': 0.9332}, {'General trash': 0.0}, {'Paper': 0.6295}, {'Paper pack': 0.0}, {'Metal': 0.0001}, {'Glass': 0.0}, {'Plastic': 0.1322}, {'Styrofoam': 0.0}, {'Plastic bag': 0.6532}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 5
# Save model in ./saved
# best model's epoch is 5
# Epoch [6/70], Step [25/328],                         Loss: 0.3402, mIoU: 0.2192
# Epoch [6/70], Step [50/328],                         Loss: 0.5406, mIoU: 0.199
# Epoch [6/70], Step [75/328],                         Loss: 0.5619, mIoU: 0.2037
# Epoch [6/70], Step [100/328],                         Loss: 0.3538, mIoU: 0.2038
# Epoch [6/70], Step [125/328],                         Loss: 0.4559, mIoU: 0.2037
# Epoch [6/70], Step [150/328],                         Loss: 0.4436, mIoU: 0.2056
# Epoch [6/70], Step [175/328],                         Loss: 0.669, mIoU: 0.207
# Epoch [6/70], Step [200/328],                         Loss: 0.3144, mIoU: 0.207
# Epoch [6/70], Step [225/328],                         Loss: 0.8533, mIoU: 0.2074
# Epoch [6/70], Step [250/328],                         Loss: 0.5461, mIoU: 0.2077
# Epoch [6/70], Step [275/328],                         Loss: 0.5632, mIoU: 0.2085
# Epoch [6/70], Step [300/328],                         Loss: 0.4021, mIoU: 0.2094
# Epoch [6/70], Step [325/328],                         Loss: 0.3971, mIoU: 0.2097
# Start validation #6
# Validation #6  Average Loss: 0.4269, Accuracy : 0.8728,                 mIoU: 0.2238
# IoU by class : [{'Backgroud': 0.936}, {'General trash': 0.0}, {'Paper': 0.6143}, {'Paper pack': 0.0}, {'Metal': 0.0029}, {'Glass': 0.0}, {'Plastic': 0.1777}, {'Styrofoam': 0.0}, {'Plastic bag': 0.731}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 6
# Save model in ./saved
# best model's epoch is 6
# Epoch [7/70], Step [25/328],                         Loss: 0.4539, mIoU: 0.2116
# Epoch [7/70], Step [50/328],                         Loss: 0.3818, mIoU: 0.2147
# Epoch [7/70], Step [75/328],                         Loss: 0.4526, mIoU: 0.2157
# Epoch [7/70], Step [100/328],                         Loss: 0.321, mIoU: 0.216
# Epoch [7/70], Step [125/328],                         Loss: 0.718, mIoU: 0.2146
# Epoch [7/70], Step [150/328],                         Loss: 0.4569, mIoU: 0.2165
# Epoch [7/70], Step [175/328],                         Loss: 0.3313, mIoU: 0.2163
# Epoch [7/70], Step [200/328],                         Loss: 0.455, mIoU: 0.2174
# Epoch [7/70], Step [225/328],                         Loss: 1.1405, mIoU: 0.217
# Epoch [7/70], Step [250/328],                         Loss: 0.4779, mIoU: 0.2166
# Epoch [7/70], Step [275/328],                         Loss: 0.363, mIoU: 0.2167
# Epoch [7/70], Step [300/328],                         Loss: 0.5702, mIoU: 0.217
# Epoch [7/70], Step [325/328],                         Loss: 0.376, mIoU: 0.2164
# Start validation #7
# Validation #7  Average Loss: 0.4283, Accuracy : 0.8717,                 mIoU: 0.2285
# IoU by class : [{'Backgroud': 0.9298}, {'General trash': 0.0}, {'Paper': 0.6154}, {'Paper pack': 0.0}, {'Metal': 0.009}, {'Glass': 0.0}, {'Plastic': 0.1885}, {'Styrofoam': 0.0}, {'Plastic bag': 0.7707}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 7
# Save model in ./saved
# best model's epoch is 7
# Epoch [8/70], Step [25/328],                         Loss: 0.8387, mIoU: 0.2184
# Epoch [8/70], Step [50/328],                         Loss: 0.4181, mIoU: 0.2191
# Epoch [8/70], Step [75/328],                         Loss: 0.5033, mIoU: 0.2203
# Epoch [8/70], Step [100/328],                         Loss: 0.4495, mIoU: 0.2189
# Epoch [8/70], Step [125/328],                         Loss: 0.7174, mIoU: 0.2203
# Epoch [8/70], Step [150/328],                         Loss: 0.6323, mIoU: 0.221
# Epoch [8/70], Step [175/328],                         Loss: 0.2822, mIoU: 0.2203
# Epoch [8/70], Step [200/328],                         Loss: 0.3825, mIoU: 0.2196
# Epoch [8/70], Step [225/328],                         Loss: 0.3347, mIoU: 0.2194
# Epoch [8/70], Step [250/328],                         Loss: 0.3876, mIoU: 0.2201
# Epoch [8/70], Step [275/328],                         Loss: 0.5977, mIoU: 0.2194
# Epoch [8/70], Step [300/328],                         Loss: 0.4644, mIoU: 0.2201
# Epoch [8/70], Step [325/328],                         Loss: 0.5117, mIoU: 0.2204
# Start validation #8
# Validation #8  Average Loss: 0.4005, Accuracy : 0.8748,                 mIoU: 0.2289
# IoU by class : [{'Backgroud': 0.9427}, {'General trash': 0.0}, {'Paper': 0.5777}, {'Paper pack': 0.0}, {'Metal': 0.0241}, {'Glass': 0.0}, {'Plastic': 0.2123}, {'Styrofoam': 0.0}, {'Plastic bag': 0.7611}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 8
# Save model in ./saved
# best model's epoch is 8
# Epoch [9/70], Step [25/328],                         Loss: 0.4627, mIoU: 0.2331
# Epoch [9/70], Step [50/328],                         Loss: 0.2891, mIoU: 0.2371
# Epoch [9/70], Step [75/328],                         Loss: 0.2686, mIoU: 0.2345
# Epoch [9/70], Step [100/328],                         Loss: 0.2158, mIoU: 0.2311
# Epoch [9/70], Step [125/328],                         Loss: 0.6195, mIoU: 0.2301
# Epoch [9/70], Step [150/328],                         Loss: 0.3028, mIoU: 0.2292
# Epoch [9/70], Step [175/328],                         Loss: 0.6951, mIoU: 0.2293
# Epoch [9/70], Step [200/328],                         Loss: 0.8749, mIoU: 0.2285
# Epoch [9/70], Step [225/328],                         Loss: 0.3689, mIoU: 0.227
# Epoch [9/70], Step [250/328],                         Loss: 0.4683, mIoU: 0.2272
# Epoch [9/70], Step [275/328],                         Loss: 0.2592, mIoU: 0.2274
# Epoch [9/70], Step [300/328],                         Loss: 0.3041, mIoU: 0.2283
# Epoch [9/70], Step [325/328],                         Loss: 0.2857, mIoU: 0.2286
# Start validation #9
# Validation #9  Average Loss: 0.3914, Accuracy : 0.8814,                 mIoU: 0.2654
# IoU by class : [{'Backgroud': 0.9417}, {'General trash': 0.0}, {'Paper': 0.6239}, {'Paper pack': 0.0}, {'Metal': 0.0071}, {'Glass': 0.0005}, {'Plastic': 0.2322}, {'Styrofoam': 0.3818}, {'Plastic bag': 0.7326}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 9
# Save model in ./saved
# best model's epoch is 9
# Epoch [10/70], Step [25/328],                         Loss: 0.3148, mIoU: 0.2525
# Epoch [10/70], Step [50/328],                         Loss: 0.4602, mIoU: 0.249
# Epoch [10/70], Step [75/328],                         Loss: 0.4355, mIoU: 0.2481
# Epoch [10/70], Step [100/328],                         Loss: 0.5336, mIoU: 0.2499
# Epoch [10/70], Step [125/328],                         Loss: 0.514, mIoU: 0.2504
# Epoch [10/70], Step [150/328],                         Loss: 0.6244, mIoU: 0.2536
# Epoch [10/70], Step [175/328],                         Loss: 0.2978, mIoU: 0.2531
# Epoch [10/70], Step [200/328],                         Loss: 0.3237, mIoU: 0.2531
# Epoch [10/70], Step [225/328],                         Loss: 0.2976, mIoU: 0.2542
# Epoch [10/70], Step [250/328],                         Loss: 0.2209, mIoU: 0.2558
# Epoch [10/70], Step [275/328],                         Loss: 0.3718, mIoU: 0.256
# Epoch [10/70], Step [300/328],                         Loss: 0.4414, mIoU: 0.2562
# Epoch [10/70], Step [325/328],                         Loss: 0.4968, mIoU: 0.2545
# Start validation #10
# Validation #10  Average Loss: 0.3765, Accuracy : 0.8863,                 mIoU: 0.2858
# IoU by class : [{'Backgroud': 0.9435}, {'General trash': 0.0007}, {'Paper': 0.6221}, {'Paper pack': 0.0}, {'Metal': 0.0207}, {'Glass': 0.0329}, {'Plastic': 0.2289}, {'Styrofoam': 0.5038}, {'Plastic bag': 0.7908}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 10
# Save model in ./saved
# best model's epoch is 10
# Epoch [11/70], Step [25/328],                         Loss: 0.2136, mIoU: 0.2832
# Epoch [11/70], Step [50/328],                         Loss: 0.2113, mIoU: 0.271
# Epoch [11/70], Step [75/328],                         Loss: 0.2085, mIoU: 0.2689
# Epoch [11/70], Step [100/328],                         Loss: 0.4216, mIoU: 0.267
# Epoch [11/70], Step [125/328],                         Loss: 0.4147, mIoU: 0.2677
# Epoch [11/70], Step [150/328],                         Loss: 0.3317, mIoU: 0.2664
# Epoch [11/70], Step [175/328],                         Loss: 0.7467, mIoU: 0.265
# Epoch [11/70], Step [200/328],                         Loss: 0.2446, mIoU: 0.2662
# Epoch [11/70], Step [225/328],                         Loss: 0.1942, mIoU: 0.2672
# Epoch [11/70], Step [250/328],                         Loss: 0.3379, mIoU: 0.2688
# Epoch [11/70], Step [275/328],                         Loss: 0.2328, mIoU: 0.268
# Epoch [11/70], Step [300/328],                         Loss: 0.2222, mIoU: 0.2685
# Epoch [11/70], Step [325/328],                         Loss: 0.3959, mIoU: 0.2691
# Start validation #11
# Validation #11  Average Loss: 0.3824, Accuracy : 0.8849,                 mIoU: 0.2888
# IoU by class : [{'Backgroud': 0.9355}, {'General trash': 0.0198}, {'Paper': 0.6177}, {'Paper pack': 0.0}, {'Metal': 0.0085}, {'Glass': 0.0716}, {'Plastic': 0.2262}, {'Styrofoam': 0.5082}, {'Plastic bag': 0.7891}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 11
# Save model in ./saved
# best model's epoch is 11
# Epoch [12/70], Step [25/328],                         Loss: 0.3283, mIoU: 0.3184
# Epoch [12/70], Step [50/328],                         Loss: 0.195, mIoU: 0.2839
# Epoch [12/70], Step [75/328],                         Loss: 0.3667, mIoU: 0.2739
# Epoch [12/70], Step [100/328],                         Loss: 0.2475, mIoU: 0.2736
# Epoch [12/70], Step [125/328],                         Loss: 0.3966, mIoU: 0.2734
# Epoch [12/70], Step [150/328],                         Loss: 0.2374, mIoU: 0.2752
# Epoch [12/70], Step [175/328],                         Loss: 0.2608, mIoU: 0.2767
# Epoch [12/70], Step [200/328],                         Loss: 0.3046, mIoU: 0.2764
# Epoch [12/70], Step [225/328],                         Loss: 0.7529, mIoU: 0.2767
# Epoch [12/70], Step [250/328],                         Loss: 0.336, mIoU: 0.2782
# Epoch [12/70], Step [275/328],                         Loss: 0.6645, mIoU: 0.2778
# Epoch [12/70], Step [300/328],                         Loss: 0.5579, mIoU: 0.2781
# Epoch [12/70], Step [325/328],                         Loss: 0.4711, mIoU: 0.2792
# Start validation #12
# Validation #12  Average Loss: 0.3633, Accuracy : 0.8881,                 mIoU: 0.3031
# IoU by class : [{'Backgroud': 0.9428}, {'General trash': 0.1066}, {'Paper': 0.6433}, {'Paper pack': 0.0}, {'Metal': 0.0022}, {'Glass': 0.0965}, {'Plastic': 0.2193}, {'Styrofoam': 0.5666}, {'Plastic bag': 0.7571}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 12
# Save model in ./saved
# best model's epoch is 12
# Epoch [13/70], Step [25/328],                         Loss: 0.564, mIoU: 0.2833
# Epoch [13/70], Step [50/328],                         Loss: 0.4752, mIoU: 0.2867
# Epoch [13/70], Step [75/328],                         Loss: 0.3868, mIoU: 0.2906
# Epoch [13/70], Step [100/328],                         Loss: 0.2544, mIoU: 0.2862
# Epoch [13/70], Step [125/328],                         Loss: 0.516, mIoU: 0.2882
# Epoch [13/70], Step [150/328],                         Loss: 0.5874, mIoU: 0.284
# Epoch [13/70], Step [175/328],                         Loss: 0.3418, mIoU: 0.2863
# Epoch [13/70], Step [200/328],                         Loss: 0.372, mIoU: 0.2881
# Epoch [13/70], Step [225/328],                         Loss: 0.5181, mIoU: 0.2888
# Epoch [13/70], Step [250/328],                         Loss: 0.3157, mIoU: 0.2889
# Epoch [13/70], Step [275/328],                         Loss: 0.2822, mIoU: 0.2897
# Epoch [13/70], Step [300/328],                         Loss: 0.3336, mIoU: 0.289
# Epoch [13/70], Step [325/328],                         Loss: 0.159, mIoU: 0.2891
# Start validation #13
# Validation #13  Average Loss: 0.3594, Accuracy : 0.8904,                 mIoU: 0.3144
# IoU by class : [{'Backgroud': 0.9434}, {'General trash': 0.2126}, {'Paper': 0.6639}, {'Paper pack': 0.0}, {'Metal': 0.0059}, {'Glass': 0.0861}, {'Plastic': 0.2145}, {'Styrofoam': 0.5714}, {'Plastic bag': 0.7604}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 13
# Save model in ./saved
# best model's epoch is 13
# Epoch [14/70], Step [25/328],                         Loss: 0.2992, mIoU: 0.2818
# Epoch [14/70], Step [50/328],                         Loss: 0.3138, mIoU: 0.3007
# Epoch [14/70], Step [75/328],                         Loss: 0.3566, mIoU: 0.3006
# Epoch [14/70], Step [100/328],                         Loss: 0.3731, mIoU: 0.2957
# Epoch [14/70], Step [125/328],                         Loss: 0.3819, mIoU: 0.3002
# Epoch [14/70], Step [150/328],                         Loss: 0.4113, mIoU: 0.3009
# Epoch [14/70], Step [175/328],                         Loss: 0.4588, mIoU: 0.3
# Epoch [14/70], Step [200/328],                         Loss: 0.2196, mIoU: 0.2972
# Epoch [14/70], Step [225/328],                         Loss: 0.3486, mIoU: 0.2967
# Epoch [14/70], Step [250/328],                         Loss: 0.5969, mIoU: 0.2975
# Epoch [14/70], Step [275/328],                         Loss: 0.3615, mIoU: 0.2968
# Epoch [14/70], Step [300/328],                         Loss: 0.2822, mIoU: 0.2959
# Epoch [14/70], Step [325/328],                         Loss: 0.1883, mIoU: 0.2975
# Start validation #14
# Validation #14  Average Loss: 0.3543, Accuracy : 0.8926,                 mIoU: 0.3242
# IoU by class : [{'Backgroud': 0.9452}, {'General trash': 0.278}, {'Paper': 0.6695}, {'Paper pack': 0.0051}, {'Metal': 0.0083}, {'Glass': 0.1142}, {'Plastic': 0.2079}, {'Styrofoam': 0.541}, {'Plastic bag': 0.7969}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 14
# Save model in ./saved
# best model's epoch is 14
# Epoch [15/70], Step [25/328],                         Loss: 0.2829, mIoU: 0.3434
# Epoch [15/70], Step [50/328],                         Loss: 0.3967, mIoU: 0.3501
# Epoch [15/70], Step [75/328],                         Loss: 0.5314, mIoU: 0.35
# Epoch [15/70], Step [100/328],                         Loss: 0.2556, mIoU: 0.314
# Epoch [15/70], Step [125/328],                         Loss: 0.3713, mIoU: 0.3102
# Epoch [15/70], Step [150/328],                         Loss: 0.324, mIoU: 0.309
# Epoch [15/70], Step [175/328],                         Loss: 0.4042, mIoU: 0.3073
# Epoch [15/70], Step [200/328],                         Loss: 0.2056, mIoU: 0.3082
# Epoch [15/70], Step [225/328],                         Loss: 0.4356, mIoU: 0.3091
# Epoch [15/70], Step [250/328],                         Loss: 0.236, mIoU: 0.3098
# Epoch [15/70], Step [275/328],                         Loss: 0.6597, mIoU: 0.3084
# Epoch [15/70], Step [300/328],                         Loss: 0.3871, mIoU: 0.3106
# Epoch [15/70], Step [325/328],                         Loss: 0.8408, mIoU: 0.3106
# Start validation #15
# Validation #15  Average Loss: 0.3555, Accuracy : 0.894,                 mIoU: 0.3268
# IoU by class : [{'Backgroud': 0.9424}, {'General trash': 0.2802}, {'Paper': 0.6638}, {'Paper pack': 0.0127}, {'Metal': 0.0045}, {'Glass': 0.1006}, {'Plastic': 0.2204}, {'Styrofoam': 0.5739}, {'Plastic bag': 0.7964}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 15
# Save model in ./saved
# best model's epoch is 15
# Epoch [16/70], Step [25/328],                         Loss: 0.5662, mIoU: 0.3282
# Epoch [16/70], Step [50/328],                         Loss: 0.3208, mIoU: 0.3203
# Epoch [16/70], Step [75/328],                         Loss: 0.4469, mIoU: 0.3193
# Epoch [16/70], Step [100/328],                         Loss: 0.3331, mIoU: 0.3184
# Epoch [16/70], Step [125/328],                         Loss: 0.4775, mIoU: 0.3159
# Epoch [16/70], Step [150/328],                         Loss: 0.2387, mIoU: 0.3154
# Epoch [16/70], Step [175/328],                         Loss: 0.2269, mIoU: 0.3151
# Epoch [16/70], Step [200/328],                         Loss: 0.5327, mIoU: 0.3136
# Epoch [16/70], Step [225/328],                         Loss: 0.1799, mIoU: 0.3149
# Epoch [16/70], Step [250/328],                         Loss: 0.2944, mIoU: 0.3165
# Epoch [16/70], Step [275/328],                         Loss: 0.3504, mIoU: 0.3154
# Epoch [16/70], Step [300/328],                         Loss: 0.181, mIoU: 0.3154
# Epoch [16/70], Step [325/328],                         Loss: 0.182, mIoU: 0.3166
# Start validation #16
# Validation #16  Average Loss: 0.3484, Accuracy : 0.8963,                 mIoU: 0.3508
# IoU by class : [{'Backgroud': 0.943}, {'General trash': 0.3398}, {'Paper': 0.687}, {'Paper pack': 0.0478}, {'Metal': 0.0027}, {'Glass': 0.1959}, {'Plastic': 0.2246}, {'Styrofoam': 0.6264}, {'Plastic bag': 0.7916}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 16
# Save model in ./saved
# best model's epoch is 16
# Epoch [17/70], Step [25/328],                         Loss: 0.5088, mIoU: 0.3118
# Epoch [17/70], Step [50/328],                         Loss: 0.2432, mIoU: 0.3199
# Epoch [17/70], Step [75/328],                         Loss: 0.1823, mIoU: 0.3202
# Epoch [17/70], Step [100/328],                         Loss: 0.3133, mIoU: 0.3244
# Epoch [17/70], Step [125/328],                         Loss: 0.2186, mIoU: 0.3285
# Epoch [17/70], Step [150/328],                         Loss: 0.3349, mIoU: 0.3293
# Epoch [17/70], Step [175/328],                         Loss: 0.4139, mIoU: 0.3293
# Epoch [17/70], Step [200/328],                         Loss: 0.3327, mIoU: 0.329
# Epoch [17/70], Step [225/328],                         Loss: 0.1487, mIoU: 0.3281
# Epoch [17/70], Step [250/328],                         Loss: 0.2904, mIoU: 0.3278
# Epoch [17/70], Step [275/328],                         Loss: 0.3226, mIoU: 0.3285
# Epoch [17/70], Step [300/328],                         Loss: 0.4034, mIoU: 0.3273
# Epoch [17/70], Step [325/328],                         Loss: 0.6025, mIoU: 0.3265
# Start validation #17
# Validation #17  Average Loss: 0.3421, Accuracy : 0.8969,                 mIoU: 0.3399
# IoU by class : [{'Backgroud': 0.9427}, {'General trash': 0.317}, {'Paper': 0.6832}, {'Paper pack': 0.0677}, {'Metal': 0.0034}, {'Glass': 0.1052}, {'Plastic': 0.2383}, {'Styrofoam': 0.5942}, {'Plastic bag': 0.7874}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Epoch [18/70], Step [25/328],                         Loss: 0.3052, mIoU: 0.3519
# Epoch [18/70], Step [50/328],                         Loss: 0.4269, mIoU: 0.3469
# Epoch [18/70], Step [75/328],                         Loss: 0.2826, mIoU: 0.3337
# Epoch [18/70], Step [100/328],                         Loss: 0.3561, mIoU: 0.3332
# Epoch [18/70], Step [125/328],                         Loss: 0.3157, mIoU: 0.338
# Epoch [18/70], Step [150/328],                         Loss: 0.2146, mIoU: 0.3363
# Epoch [18/70], Step [175/328],                         Loss: 0.248, mIoU: 0.337
# Epoch [18/70], Step [200/328],                         Loss: 0.2487, mIoU: 0.3364
# Epoch [18/70], Step [225/328],                         Loss: 0.3819, mIoU: 0.3363
# Epoch [18/70], Step [250/328],                         Loss: 0.2577, mIoU: 0.3356
# Epoch [18/70], Step [275/328],                         Loss: 0.2625, mIoU: 0.3337
# Epoch [18/70], Step [300/328],                         Loss: 0.3512, mIoU: 0.335
# Epoch [18/70], Step [325/328],                         Loss: 0.6069, mIoU: 0.3342
# Start validation #18
# Validation #18  Average Loss: 0.3405, Accuracy : 0.8998,                 mIoU: 0.362
# IoU by class : [{'Backgroud': 0.9449}, {'General trash': 0.3334}, {'Paper': 0.6737}, {'Paper pack': 0.0841}, {'Metal': 0.014}, {'Glass': 0.2658}, {'Plastic': 0.2458}, {'Styrofoam': 0.617}, {'Plastic bag': 0.8036}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 18
# Save model in ./saved
# best model's epoch is 18
# Epoch [19/70], Step [25/328],                         Loss: 0.2238, mIoU: 0.3901
# Epoch [19/70], Step [50/328],                         Loss: 0.3741, mIoU: 0.3435
# Epoch [19/70], Step [75/328],                         Loss: 0.1319, mIoU: 0.3473
# Epoch [19/70], Step [100/328],                         Loss: 0.4335, mIoU: 0.3469
# Epoch [19/70], Step [125/328],                         Loss: 0.2653, mIoU: 0.3466
# Epoch [19/70], Step [150/328],                         Loss: 0.3225, mIoU: 0.3417
# Epoch [19/70], Step [175/328],                         Loss: 0.2603, mIoU: 0.3397
# Epoch [19/70], Step [200/328],                         Loss: 0.2086, mIoU: 0.3403
# Epoch [19/70], Step [225/328],                         Loss: 0.2921, mIoU: 0.3404
# Epoch [19/70], Step [250/328],                         Loss: 0.391, mIoU: 0.3392
# Epoch [19/70], Step [275/328],                         Loss: 0.4353, mIoU: 0.3401
# Epoch [19/70], Step [300/328],                         Loss: 0.3243, mIoU: 0.3395
# Epoch [19/70], Step [325/328],                         Loss: 0.3624, mIoU: 0.3381
# Start validation #19
# Validation #19  Average Loss: 0.3368, Accuracy : 0.9005,                 mIoU: 0.3678
# IoU by class : [{'Backgroud': 0.944}, {'General trash': 0.3344}, {'Paper': 0.6771}, {'Paper pack': 0.1224}, {'Metal': 0.0223}, {'Glass': 0.2366}, {'Plastic': 0.2614}, {'Styrofoam': 0.6448}, {'Plastic bag': 0.8032}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 19
# Save model in ./saved
# best model's epoch is 19
# Epoch [20/70], Step [25/328],                         Loss: 0.2347, mIoU: 0.3456
# Epoch [20/70], Step [50/328],                         Loss: 0.4693, mIoU: 0.3382
# Epoch [20/70], Step [75/328],                         Loss: 0.3554, mIoU: 0.3383
# Epoch [20/70], Step [100/328],                         Loss: 0.2579, mIoU: 0.3428
# Epoch [20/70], Step [125/328],                         Loss: 0.2732, mIoU: 0.3473
# Epoch [20/70], Step [150/328],                         Loss: 0.3979, mIoU: 0.3457
# Epoch [20/70], Step [175/328],                         Loss: 0.1856, mIoU: 0.3444
# Epoch [20/70], Step [200/328],                         Loss: 0.4191, mIoU: 0.3431
# Epoch [20/70], Step [225/328],                         Loss: 0.2476, mIoU: 0.3449
# Epoch [20/70], Step [250/328],                         Loss: 0.341, mIoU: 0.3434
# Epoch [20/70], Step [275/328],                         Loss: 0.2607, mIoU: 0.3428
# Epoch [20/70], Step [300/328],                         Loss: 0.3372, mIoU: 0.3429
# Epoch [20/70], Step [325/328],                         Loss: 0.3674, mIoU: 0.3435
# Start validation #20
# Validation #20  Average Loss: 0.3423, Accuracy : 0.8993,                 mIoU: 0.3717
# IoU by class : [{'Backgroud': 0.9443}, {'General trash': 0.3834}, {'Paper': 0.6857}, {'Paper pack': 0.2106}, {'Metal': 0.0094}, {'Glass': 0.2161}, {'Plastic': 0.2437}, {'Styrofoam': 0.5987}, {'Plastic bag': 0.7967}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 20
# Save model in ./saved
# best model's epoch is 20
# Epoch [21/70], Step [25/328],                         Loss: 0.1929, mIoU: 0.3517
# Epoch [21/70], Step [50/328],                         Loss: 0.4186, mIoU: 0.3458
# Epoch [21/70], Step [75/328],                         Loss: 0.6162, mIoU: 0.3575
# Epoch [21/70], Step [100/328],                         Loss: 0.4376, mIoU: 0.3574
# Epoch [21/70], Step [125/328],                         Loss: 0.2783, mIoU: 0.3605
# Epoch [21/70], Step [150/328],                         Loss: 0.4479, mIoU: 0.3592
# Epoch [21/70], Step [175/328],                         Loss: 0.6399, mIoU: 0.3578
# Epoch [21/70], Step [200/328],                         Loss: 0.4648, mIoU: 0.3585
# Epoch [21/70], Step [225/328],                         Loss: 0.1446, mIoU: 0.3572
# Epoch [21/70], Step [250/328],                         Loss: 0.2937, mIoU: 0.3564
# Epoch [21/70], Step [275/328],                         Loss: 0.1911, mIoU: 0.3579
# Epoch [21/70], Step [300/328],                         Loss: 0.4174, mIoU: 0.3584
# Epoch [21/70], Step [325/328],                         Loss: 0.2844, mIoU: 0.3579
# Start validation #21
# Validation #21  Average Loss: 0.343, Accuracy : 0.9031,                 mIoU: 0.3943
# IoU by class : [{'Backgroud': 0.9421}, {'General trash': 0.3748}, {'Paper': 0.6919}, {'Paper pack': 0.2236}, {'Metal': 0.0311}, {'Glass': 0.3909}, {'Plastic': 0.2567}, {'Styrofoam': 0.6195}, {'Plastic bag': 0.8063}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 21
# Save model in ./saved
# best model's epoch is 21
# Epoch [22/70], Step [25/328],                         Loss: 0.3494, mIoU: 0.379
# Epoch [22/70], Step [50/328],                         Loss: 0.2417, mIoU: 0.3665
# Epoch [22/70], Step [75/328],                         Loss: 0.305, mIoU: 0.3631
# Epoch [22/70], Step [100/328],                         Loss: 0.2885, mIoU: 0.3668
# Epoch [22/70], Step [125/328],                         Loss: 0.1966, mIoU: 0.369
# Epoch [22/70], Step [150/328],                         Loss: 0.2787, mIoU: 0.3673
# Epoch [22/70], Step [175/328],                         Loss: 0.3586, mIoU: 0.3697
# Epoch [22/70], Step [200/328],                         Loss: 0.3016, mIoU: 0.3689
# Epoch [22/70], Step [225/328],                         Loss: 0.37, mIoU: 0.367
# Epoch [22/70], Step [250/328],                         Loss: 0.279, mIoU: 0.3685
# Epoch [22/70], Step [275/328],                         Loss: 0.4307, mIoU: 0.3668
# Epoch [22/70], Step [300/328],                         Loss: 0.3766, mIoU: 0.3667
# Epoch [22/70], Step [325/328],                         Loss: 0.3109, mIoU: 0.3659
# Start validation #22
# Validation #22  Average Loss: 0.3307, Accuracy : 0.9016,                 mIoU: 0.3809
# IoU by class : [{'Backgroud': 0.9449}, {'General trash': 0.3518}, {'Paper': 0.6875}, {'Paper pack': 0.2122}, {'Metal': 0.0287}, {'Glass': 0.3054}, {'Plastic': 0.2459}, {'Styrofoam': 0.6185}, {'Plastic bag': 0.7953}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Epoch [23/70], Step [25/328],                         Loss: 0.1643, mIoU: 0.372
# Epoch [23/70], Step [50/328],                         Loss: 0.1404, mIoU: 0.3641
# Epoch [23/70], Step [75/328],                         Loss: 0.2924, mIoU: 0.3682
# Epoch [23/70], Step [100/328],                         Loss: 0.5559, mIoU: 0.371
# Epoch [23/70], Step [125/328],                         Loss: 0.4705, mIoU: 0.3761
# Epoch [23/70], Step [150/328],                         Loss: 0.2488, mIoU: 0.3781
# Epoch [23/70], Step [175/328],                         Loss: 0.2899, mIoU: 0.3768
# Epoch [23/70], Step [200/328],                         Loss: 0.2003, mIoU: 0.3781
# Epoch [23/70], Step [225/328],                         Loss: 0.4717, mIoU: 0.3789
# Epoch [23/70], Step [250/328],                         Loss: 0.208, mIoU: 0.3784
# Epoch [23/70], Step [275/328],                         Loss: 0.1378, mIoU: 0.3778
# Epoch [23/70], Step [300/328],                         Loss: 0.1402, mIoU: 0.3777
# Epoch [23/70], Step [325/328],                         Loss: 0.2874, mIoU: 0.3791
# Start validation #23
# Validation #23  Average Loss: 0.3383, Accuracy : 0.9041,                 mIoU: 0.3993
# IoU by class : [{'Backgroud': 0.9443}, {'General trash': 0.3767}, {'Paper': 0.6955}, {'Paper pack': 0.2821}, {'Metal': 0.0492}, {'Glass': 0.4562}, {'Plastic': 0.2355}, {'Styrofoam': 0.5522}, {'Plastic bag': 0.8006}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 23
# Save model in ./saved
# best model's epoch is 23
# Epoch [24/70], Step [25/328],                         Loss: 0.1346, mIoU: 0.4411
# Epoch [24/70], Step [50/328],                         Loss: 0.2578, mIoU: 0.401
# Epoch [24/70], Step [75/328],                         Loss: 0.2074, mIoU: 0.3882
# Epoch [24/70], Step [100/328],                         Loss: 0.2396, mIoU: 0.3841
# Epoch [24/70], Step [125/328],                         Loss: 0.1683, mIoU: 0.3862
# Epoch [24/70], Step [150/328],                         Loss: 0.2634, mIoU: 0.3861
# Epoch [24/70], Step [175/328],                         Loss: 0.3564, mIoU: 0.3878
# Epoch [24/70], Step [200/328],                         Loss: 0.1629, mIoU: 0.3868
# Epoch [24/70], Step [225/328],                         Loss: 0.483, mIoU: 0.3949
# Epoch [24/70], Step [250/328],                         Loss: 0.2068, mIoU: 0.394
# Epoch [24/70], Step [275/328],                         Loss: 0.3845, mIoU: 0.395
# Epoch [24/70], Step [300/328],                         Loss: 0.3545, mIoU: 0.3964
# Epoch [24/70], Step [325/328],                         Loss: 0.2662, mIoU: 0.3961
# Start validation #24
# Validation #24  Average Loss: 0.3367, Accuracy : 0.9033,                 mIoU: 0.3871
# IoU by class : [{'Backgroud': 0.9453}, {'General trash': 0.3614}, {'Paper': 0.6746}, {'Paper pack': 0.2363}, {'Metal': 0.0455}, {'Glass': 0.3931}, {'Plastic': 0.2522}, {'Styrofoam': 0.5544}, {'Plastic bag': 0.7954}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Epoch [25/70], Step [25/328],                         Loss: 0.2414, mIoU: 0.4564
# Epoch [25/70], Step [50/328],                         Loss: 0.1831, mIoU: 0.3935
# Epoch [25/70], Step [75/328],                         Loss: 0.2884, mIoU: 0.4121
# Epoch [25/70], Step [100/328],                         Loss: 0.2442, mIoU: 0.4018
# Epoch [25/70], Step [125/328],                         Loss: 0.2823, mIoU: 0.3973
# Epoch [25/70], Step [150/328],                         Loss: 0.2203, mIoU: 0.3957
# Epoch [25/70], Step [175/328],                         Loss: 0.2265, mIoU: 0.3967
# Epoch [25/70], Step [200/328],                         Loss: 0.1476, mIoU: 0.4016
# Epoch [25/70], Step [225/328],                         Loss: 0.209, mIoU: 0.4022
# Epoch [25/70], Step [250/328],                         Loss: 0.3416, mIoU: 0.4029
# Epoch [25/70], Step [275/328],                         Loss: 0.3021, mIoU: 0.4019
# Epoch [25/70], Step [300/328],                         Loss: 0.132, mIoU: 0.3999
# Epoch [25/70], Step [325/328],                         Loss: 0.3354, mIoU: 0.3979
# Start validation #25
# Validation #25  Average Loss: 0.3442, Accuracy : 0.9027,                 mIoU: 0.4124
# IoU by class : [{'Backgroud': 0.9425}, {'General trash': 0.3887}, {'Paper': 0.683}, {'Paper pack': 0.3381}, {'Metal': 0.0652}, {'Glass': 0.4189}, {'Plastic': 0.2613}, {'Styrofoam': 0.6487}, {'Plastic bag': 0.7905}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 25
# Save model in ./saved
# best model's epoch is 25
# Epoch [26/70], Step [25/328],                         Loss: 0.3344, mIoU: 0.4098
# Epoch [26/70], Step [50/328],                         Loss: 0.1399, mIoU: 0.4029
# Epoch [26/70], Step [75/328],                         Loss: 0.1914, mIoU: 0.4038
# Epoch [26/70], Step [100/328],                         Loss: 0.2233, mIoU: 0.4093
# Epoch [26/70], Step [125/328],                         Loss: 0.1962, mIoU: 0.4167
# Epoch [26/70], Step [150/328],                         Loss: 0.3124, mIoU: 0.4147
# Epoch [26/70], Step [175/328],                         Loss: 0.3993, mIoU: 0.4097
# Epoch [26/70], Step [200/328],                         Loss: 0.6193, mIoU: 0.412
# Epoch [26/70], Step [225/328],                         Loss: 0.2311, mIoU: 0.4124
# Epoch [26/70], Step [250/328],                         Loss: 0.3039, mIoU: 0.4108
# Epoch [26/70], Step [275/328],                         Loss: 0.2097, mIoU: 0.4099
# Epoch [26/70], Step [300/328],                         Loss: 0.2396, mIoU: 0.4088
# Epoch [26/70], Step [325/328],                         Loss: 0.4813, mIoU: 0.4083
# Start validation #26
# Validation #26  Average Loss: 0.3522, Accuracy : 0.9004,                 mIoU: 0.3976
# IoU by class : [{'Backgroud': 0.9386}, {'General trash': 0.3017}, {'Paper': 0.6698}, {'Paper pack': 0.2946}, {'Metal': 0.0564}, {'Glass': 0.426}, {'Plastic': 0.2824}, {'Styrofoam': 0.6126}, {'Plastic bag': 0.7919}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Epoch [27/70], Step [25/328],                         Loss: 0.3078, mIoU: 0.3873
# Epoch [27/70], Step [50/328],                         Loss: 0.4289, mIoU: 0.3977
# Epoch [27/70], Step [75/328],                         Loss: 0.2319, mIoU: 0.4046
# Epoch [27/70], Step [100/328],                         Loss: 0.2963, mIoU: 0.4155
# Epoch [27/70], Step [125/328],                         Loss: 0.4738, mIoU: 0.4085
# Epoch [27/70], Step [150/328],                         Loss: 0.1564, mIoU: 0.4097
# Epoch [27/70], Step [175/328],                         Loss: 0.225, mIoU: 0.4121
# Epoch [27/70], Step [200/328],                         Loss: 0.1918, mIoU: 0.4153
# Epoch [27/70], Step [225/328],                         Loss: 0.2069, mIoU: 0.4188
# Epoch [27/70], Step [250/328],                         Loss: 0.3553, mIoU: 0.4187
# Epoch [27/70], Step [275/328],                         Loss: 0.2509, mIoU: 0.4194
# Epoch [27/70], Step [300/328],                         Loss: 0.2932, mIoU: 0.4182
# Epoch [27/70], Step [325/328],                         Loss: 0.2212, mIoU: 0.4164
# Start validation #27
# Validation #27  Average Loss: 0.3434, Accuracy : 0.9035,                 mIoU: 0.4079
# IoU by class : [{'Backgroud': 0.9461}, {'General trash': 0.3697}, {'Paper': 0.6781}, {'Paper pack': 0.2279}, {'Metal': 0.1138}, {'Glass': 0.4705}, {'Plastic': 0.2834}, {'Styrofoam': 0.598}, {'Plastic bag': 0.7995}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Epoch [28/70], Step [25/328],                         Loss: 0.1876, mIoU: 0.4176
# Epoch [28/70], Step [50/328],                         Loss: 0.2628, mIoU: 0.4302
# Epoch [28/70], Step [75/328],                         Loss: 0.2219, mIoU: 0.4371
# Epoch [28/70], Step [100/328],                         Loss: 0.3384, mIoU: 0.4373
# Epoch [28/70], Step [125/328],                         Loss: 0.2318, mIoU: 0.4379
# Epoch [28/70], Step [150/328],                         Loss: 0.3719, mIoU: 0.4382
# Epoch [28/70], Step [175/328],                         Loss: 0.3933, mIoU: 0.4384
# Epoch [28/70], Step [200/328],                         Loss: 0.1412, mIoU: 0.4368
# Epoch [28/70], Step [225/328],                         Loss: 0.1653, mIoU: 0.438
# Epoch [28/70], Step [250/328],                         Loss: 0.254, mIoU: 0.4386
# Epoch [28/70], Step [275/328],                         Loss: 0.376, mIoU: 0.4377
# Epoch [28/70], Step [300/328],                         Loss: 0.4022, mIoU: 0.4372
# Epoch [28/70], Step [325/328],                         Loss: 0.4958, mIoU: 0.4352
# Start validation #28
# Validation #28  Average Loss: 0.3492, Accuracy : 0.9051,                 mIoU: 0.4244
# IoU by class : [{'Backgroud': 0.945}, {'General trash': 0.389}, {'Paper': 0.6935}, {'Paper pack': 0.376}, {'Metal': 0.0862}, {'Glass': 0.4978}, {'Plastic': 0.2778}, {'Styrofoam': 0.6157}, {'Plastic bag': 0.7876}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 28
# Save model in ./saved
# best model's epoch is 28
# Epoch [29/70], Step [25/328],                         Loss: 0.1494, mIoU: 0.408
# Epoch [29/70], Step [50/328],                         Loss: 0.6168, mIoU: 0.4303
# Epoch [29/70], Step [75/328],                         Loss: 0.1199, mIoU: 0.4235
# Epoch [29/70], Step [100/328],                         Loss: 0.1295, mIoU: 0.422
# Epoch [29/70], Step [125/328],                         Loss: 0.2172, mIoU: 0.4193
# Epoch [29/70], Step [150/328],                         Loss: 0.4217, mIoU: 0.4179
# Epoch [29/70], Step [175/328],                         Loss: 0.2921, mIoU: 0.4242
# Epoch [29/70], Step [200/328],                         Loss: 0.3826, mIoU: 0.4313
# Epoch [29/70], Step [225/328],                         Loss: 0.3537, mIoU: 0.4342
# Epoch [29/70], Step [250/328],                         Loss: 0.2373, mIoU: 0.4364
# Epoch [29/70], Step [275/328],                         Loss: 0.3516, mIoU: 0.4348
# Epoch [29/70], Step [300/328],                         Loss: 0.1908, mIoU: 0.438
# Epoch [29/70], Step [325/328],                         Loss: 0.1896, mIoU: 0.4378
# Start validation #29
# Validation #29  Average Loss: 0.333, Accuracy : 0.9083,                 mIoU: 0.4245
# IoU by class : [{'Backgroud': 0.9467}, {'General trash': 0.3814}, {'Paper': 0.701}, {'Paper pack': 0.3123}, {'Metal': 0.0789}, {'Glass': 0.5269}, {'Plastic': 0.3}, {'Styrofoam': 0.642}, {'Plastic bag': 0.7803}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 29
# Save model in ./saved
# best model's epoch is 29
# Epoch [30/70], Step [25/328],                         Loss: 0.1505, mIoU: 0.4984
# Epoch [30/70], Step [50/328],                         Loss: 0.3004, mIoU: 0.4666
# Epoch [30/70], Step [75/328],                         Loss: 0.4513, mIoU: 0.4614
# Epoch [30/70], Step [100/328],                         Loss: 0.1503, mIoU: 0.4538
# Epoch [30/70], Step [125/328],                         Loss: 0.265, mIoU: 0.4503
# Epoch [30/70], Step [150/328],                         Loss: 0.1965, mIoU: 0.4518
# Epoch [30/70], Step [175/328],                         Loss: 0.1983, mIoU: 0.4531
# Epoch [30/70], Step [200/328],                         Loss: 0.2041, mIoU: 0.4507
# Epoch [30/70], Step [225/328],                         Loss: 0.2212, mIoU: 0.4493
# Epoch [30/70], Step [250/328],                         Loss: 0.3015, mIoU: 0.4502
# Epoch [30/70], Step [275/328],                         Loss: 0.142, mIoU: 0.4522
# Epoch [30/70], Step [300/328],                         Loss: 0.1861, mIoU: 0.4516
# Epoch [30/70], Step [325/328],                         Loss: 0.2657, mIoU: 0.4509
# Start validation #30
# Validation #30  Average Loss: 0.3323, Accuracy : 0.9076,                 mIoU: 0.4349
# IoU by class : [{'Backgroud': 0.9468}, {'General trash': 0.3919}, {'Paper': 0.6957}, {'Paper pack': 0.366}, {'Metal': 0.2224}, {'Glass': 0.4484}, {'Plastic': 0.2835}, {'Styrofoam': 0.6297}, {'Plastic bag': 0.7994}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 30
# Save model in ./saved
# best model's epoch is 30
# Epoch [31/70], Step [25/328],                         Loss: 0.2409, mIoU: 0.4677
# Epoch [31/70], Step [50/328],                         Loss: 0.3945, mIoU: 0.4552
# Epoch [31/70], Step [75/328],                         Loss: 0.1725, mIoU: 0.4631
# Epoch [31/70], Step [100/328],                         Loss: 0.1267, mIoU: 0.4682
# Epoch [31/70], Step [125/328],                         Loss: 0.2024, mIoU: 0.4657
# Epoch [31/70], Step [150/328],                         Loss: 0.2658, mIoU: 0.4632
# Epoch [31/70], Step [175/328],                         Loss: 0.1808, mIoU: 0.4669
# Epoch [31/70], Step [200/328],                         Loss: 0.1746, mIoU: 0.4638
# Epoch [31/70], Step [225/328],                         Loss: 0.1636, mIoU: 0.4619
# Epoch [31/70], Step [250/328],                         Loss: 0.1897, mIoU: 0.4596
# Epoch [31/70], Step [275/328],                         Loss: 0.188, mIoU: 0.4575
# Epoch [31/70], Step [300/328],                         Loss: 0.2441, mIoU: 0.4576
# Epoch [31/70], Step [325/328],                         Loss: 0.5578, mIoU: 0.4596
# Start validation #31
# Validation #31  Average Loss: 0.3283, Accuracy : 0.9096,                 mIoU: 0.4354
# IoU by class : [{'Backgroud': 0.9442}, {'General trash': 0.3985}, {'Paper': 0.7012}, {'Paper pack': 0.3331}, {'Metal': 0.2014}, {'Glass': 0.4626}, {'Plastic': 0.319}, {'Styrofoam': 0.6201}, {'Plastic bag': 0.8093}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 31
# Save model in ./saved
# best model's epoch is 31
# Epoch [32/70], Step [25/328],                         Loss: 0.1274, mIoU: 0.4599
# Epoch [32/70], Step [50/328],                         Loss: 0.1742, mIoU: 0.4603
# Epoch [32/70], Step [75/328],                         Loss: 0.1233, mIoU: 0.468
# Epoch [32/70], Step [100/328],                         Loss: 0.2801, mIoU: 0.4649
# Epoch [32/70], Step [125/328],                         Loss: 0.2093, mIoU: 0.4658
# Epoch [32/70], Step [150/328],                         Loss: 0.3834, mIoU: 0.4605
# Epoch [32/70], Step [175/328],                         Loss: 0.3036, mIoU: 0.461
# Epoch [32/70], Step [200/328],                         Loss: 0.4131, mIoU: 0.4605
# Epoch [32/70], Step [225/328],                         Loss: 0.2096, mIoU: 0.4587
# Epoch [32/70], Step [250/328],                         Loss: 0.1683, mIoU: 0.4606
# Epoch [32/70], Step [275/328],                         Loss: 0.1214, mIoU: 0.4628
# Epoch [32/70], Step [300/328],                         Loss: 0.2637, mIoU: 0.4655
# Epoch [32/70], Step [325/328],                         Loss: 0.4488, mIoU: 0.4669
# Start validation #32
# Validation #32  Average Loss: 0.3336, Accuracy : 0.9091,                 mIoU: 0.4418
# IoU by class : [{'Backgroud': 0.947}, {'General trash': 0.3767}, {'Paper': 0.6911}, {'Paper pack': 0.3511}, {'Metal': 0.2129}, {'Glass': 0.5203}, {'Plastic': 0.3283}, {'Styrofoam': 0.6368}, {'Plastic bag': 0.7952}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 32
# Save model in ./saved
# best model's epoch is 32
# Epoch [33/70], Step [25/328],                         Loss: 0.1942, mIoU: 0.4704
# Epoch [33/70], Step [50/328],                         Loss: 0.2621, mIoU: 0.4621
# Epoch [33/70], Step [75/328],                         Loss: 0.2019, mIoU: 0.4731
# ...
# Epoch [48/70], Step [300/328],                         Loss: 0.1096, mIoU: 0.6061
# Epoch [48/70], Step [325/328],                         Loss: 0.2737, mIoU: 0.6014
# Start validation #48
# Validation #48  Average Loss: 0.354, Accuracy : 0.9085,                 mIoU: 0.4839
# IoU by class : [{'Backgroud': 0.9443}, {'General trash': 0.3843}, {'Paper': 0.7116}, {'Paper pack': 0.4109}, {'Metal': 0.2703}, {'Glass': 0.4283}, {'Plastic': 0.3118}, {'Styrofoam': 0.666}, {'Plastic bag': 0.7913}, {'Battery': 0.0}, {'Clothing': 0.4038}]
# Epoch [49/70], Step [25/328],                         Loss: 0.1006, mIoU: 0.6216
# Epoch [49/70], Step [50/328],                         Loss: 0.1416, mIoU: 0.6111
# Epoch [49/70], Step [75/328],                         Loss: 0.1833, mIoU: 0.5934
# Epoch [49/70], Step [100/328],                         Loss: 0.1658, mIoU: 0.6112
# Epoch [49/70], Step [125/328],                         Loss: 0.1159, mIoU: 0.6004
# Epoch [49/70], Step [150/328],                         Loss: 0.1481, mIoU: 0.6006
# Epoch [49/70], Step [175/328],                         Loss: 0.1678, mIoU: 0.6033
# Epoch [49/70], Step [200/328],                         Loss: 0.1635, mIoU: 0.6035
# Epoch [49/70], Step [225/328],                         Loss: 0.2946, mIoU: 0.604
# Epoch [49/70], Step [250/328],                         Loss: 0.1774, mIoU: 0.5995
# Epoch [49/70], Step [275/328],                         Loss: 0.105, mIoU: 0.6014
# Epoch [49/70], Step [300/328],                         Loss: 0.1424, mIoU: 0.6031
# Epoch [49/70], Step [325/328],                         Loss: 0.162, mIoU: 0.6069
# Start validation #49
# Validation #49  Average Loss: 0.3419, Accuracy : 0.9149,                 mIoU: 0.4925
# IoU by class : [{'Backgroud': 0.9478}, {'General trash': 0.4245}, {'Paper': 0.7203}, {'Paper pack': 0.4211}, {'Metal': 0.2933}, {'Glass': 0.4254}, {'Plastic': 0.3078}, {'Styrofoam': 0.6392}, {'Plastic bag': 0.8156}, {'Battery': 0.0}, {'Clothing': 0.4229}]
# Epoch [50/70], Step [25/328],                         Loss: 0.1994, mIoU: 0.5861
# Epoch [50/70], Step [50/328],                         Loss: 0.1538, mIoU: 0.5795
# Epoch [50/70], Step [75/328],                         Loss: 0.2096, mIoU: 0.5897
# Epoch [50/70], Step [100/328],                         Loss: 0.151, mIoU: 0.591
# Epoch [50/70], Step [125/328],                         Loss: 0.1478, mIoU: 0.5966
# Epoch [50/70], Step [150/328],                         Loss: 0.182, mIoU: 0.5967
# Epoch [50/70], Step [175/328],                         Loss: 0.1666, mIoU: 0.6007
# Epoch [50/70], Step [200/328],                         Loss: 0.2033, mIoU: 0.6005
# Epoch [50/70], Step [225/328],                         Loss: 0.1831, mIoU: 0.6017
# Epoch [50/70], Step [250/328],                         Loss: 0.1111, mIoU: 0.6052
# Epoch [50/70], Step [275/328],                         Loss: 0.1581, mIoU: 0.602
# Epoch [50/70], Step [300/328],                         Loss: 0.5461, mIoU: 0.6061
# Epoch [50/70], Step [325/328],                         Loss: 0.2229, mIoU: 0.6053
# Start validation #50
# Validation #50  Average Loss: 0.3663, Accuracy : 0.9118,                 mIoU: 0.494
# IoU by class : [{'Backgroud': 0.9443}, {'General trash': 0.4161}, {'Paper': 0.6932}, {'Paper pack': 0.4958}, {'Metal': 0.3086}, {'Glass': 0.3945}, {'Plastic': 0.3316}, {'Styrofoam': 0.6364}, {'Plastic bag': 0.8107}, {'Battery': 0.0}, {'Clothing': 0.4028}]
# Epoch [51/70], Step [25/328],                         Loss: 0.1334, mIoU: 0.5921
# Epoch [51/70], Step [50/328],                         Loss: 0.1534, mIoU: 0.6158
# Epoch [51/70], Step [75/328],                         Loss: 0.1851, mIoU: 0.5976
# Epoch [51/70], Step [100/328],                         Loss: 0.1765, mIoU: 0.59
# Epoch [51/70], Step [125/328],                         Loss: 0.0586, mIoU: 0.5922
# Epoch [51/70], Step [150/328],                         Loss: 0.1902, mIoU: 0.5977
# Epoch [51/70], Step [175/328],                         Loss: 0.3144, mIoU: 0.5977
# Epoch [51/70], Step [200/328],                         Loss: 0.2632, mIoU: 0.598
# Epoch [51/70], Step [225/328],                         Loss: 0.2213, mIoU: 0.5961
# Epoch [51/70], Step [250/328],                         Loss: 0.12, mIoU: 0.598
# Epoch [51/70], Step [275/328],                         Loss: 0.3518, mIoU: 0.596
# Epoch [51/70], Step [300/328],                         Loss: 0.2003, mIoU: 0.5986
# Epoch [51/70], Step [325/328],                         Loss: 0.6003, mIoU: 0.5956
# Start validation #51
# Validation #51  Average Loss: 0.3581, Accuracy : 0.9124,                 mIoU: 0.4904
# IoU by class : [{'Backgroud': 0.9442}, {'General trash': 0.4151}, {'Paper': 0.7039}, {'Paper pack': 0.3945}, {'Metal': 0.3176}, {'Glass': 0.4853}, {'Plastic': 0.2814}, {'Styrofoam': 0.6312}, {'Plastic bag': 0.8104}, {'Battery': 0.0}, {'Clothing': 0.4104}]
# Epoch [52/70], Step [25/328],                         Loss: 0.2597, mIoU: 0.6745
# Epoch [52/70], Step [50/328],                         Loss: 0.1632, mIoU: 0.6477
# Epoch [52/70], Step [75/328],                         Loss: 0.3516, mIoU: 0.6365
# Epoch [52/70], Step [100/328],                         Loss: 0.4354, mIoU: 0.6268
# Epoch [52/70], Step [125/328],                         Loss: 0.1983, mIoU: 0.6326
# Epoch [52/70], Step [150/328],                         Loss: 0.2041, mIoU: 0.6316
# Epoch [52/70], Step [175/328],                         Loss: 0.232, mIoU: 0.6302
# Epoch [52/70], Step [200/328],                         Loss: 0.1971, mIoU: 0.6316
# Epoch [52/70], Step [225/328],                         Loss: 0.2737, mIoU: 0.626
# Epoch [52/70], Step [250/328],                         Loss: 0.1665, mIoU: 0.6279
# Epoch [52/70], Step [275/328],                         Loss: 0.1471, mIoU: 0.6287
# Epoch [52/70], Step [300/328],                         Loss: 0.1783, mIoU: 0.6274
# Epoch [52/70], Step [325/328],                         Loss: 0.1688, mIoU: 0.6259
# Start validation #52
# Validation #52  Average Loss: 0.3423, Accuracy : 0.9132,                 mIoU: 0.4832
# IoU by class : [{'Backgroud': 0.9476}, {'General trash': 0.4045}, {'Paper': 0.7111}, {'Paper pack': 0.4537}, {'Metal': 0.2091}, {'Glass': 0.3796}, {'Plastic': 0.3267}, {'Styrofoam': 0.6786}, {'Plastic bag': 0.8127}, {'Battery': 0.0}, {'Clothing': 0.3919}]
# Epoch [53/70], Step [25/328],                         Loss: 0.1481, mIoU: 0.6514
# Epoch [53/70], Step [50/328],                         Loss: 0.2144, mIoU: 0.6483
# Epoch [53/70], Step [75/328],                         Loss: 0.108, mIoU: 0.6454
# Epoch [53/70], Step [100/328],                         Loss: 0.3098, mIoU: 0.635
# Epoch [53/70], Step [125/328],                         Loss: 0.1771, mIoU: 0.6216
# Epoch [53/70], Step [150/328],                         Loss: 0.1861, mIoU: 0.619
# Epoch [53/70], Step [175/328],                         Loss: 0.097, mIoU: 0.6197
# Epoch [53/70], Step [200/328],                         Loss: 0.1328, mIoU: 0.6195
# Epoch [53/70], Step [225/328],                         Loss: 0.1194, mIoU: 0.6152
# Epoch [53/70], Step [250/328],                         Loss: 0.2019, mIoU: 0.6214
# Epoch [53/70], Step [275/328],                         Loss: 0.1906, mIoU: 0.621
# Epoch [53/70], Step [300/328],                         Loss: 0.1894, mIoU: 0.6197
# Epoch [53/70], Step [325/328],                         Loss: 0.2168, mIoU: 0.62
# Start validation #53
# Validation #53  Average Loss: 0.3542, Accuracy : 0.9141,                 mIoU: 0.498
# IoU by class : [{'Backgroud': 0.9465}, {'General trash': 0.4129}, {'Paper': 0.7239}, {'Paper pack': 0.4471}, {'Metal': 0.3197}, {'Glass': 0.4277}, {'Plastic': 0.3204}, {'Styrofoam': 0.6666}, {'Plastic bag': 0.8108}, {'Battery': 0.0}, {'Clothing': 0.403}]
# Best performance at epoch: 53
# Save model in ./saved
# best model's epoch is 53
# Epoch [54/70], Step [25/328],                         Loss: 0.2538, mIoU: 0.6657
# Epoch [54/70], Step [50/328],                         Loss: 0.2379, mIoU: 0.6683
# Epoch [54/70], Step [75/328],                         Loss: 0.1434, mIoU: 0.6607
# Epoch [54/70], Step [100/328],                         Loss: 0.2406, mIoU: 0.6537
# Epoch [54/70], Step [125/328],                         Loss: 0.1736, mIoU: 0.6457
# Epoch [54/70], Step [150/328],                         Loss: 0.0817, mIoU: 0.6381
# Epoch [54/70], Step [175/328],                         Loss: 0.1877, mIoU: 0.6384
# Epoch [54/70], Step [200/328],                         Loss: 0.3068, mIoU: 0.6419
# Epoch [54/70], Step [225/328],                         Loss: 0.1699, mIoU: 0.6373
# Epoch [54/70], Step [250/328],                         Loss: 0.1633, mIoU: 0.6361
# Epoch [54/70], Step [275/328],                         Loss: 0.1378, mIoU: 0.6362
# Epoch [54/70], Step [300/328],                         Loss: 0.1778, mIoU: 0.6362
# Epoch [54/70], Step [325/328],                         Loss: 0.1989, mIoU: 0.6357
# Start validation #54
# Validation #54  Average Loss: 0.3544, Accuracy : 0.9147,                 mIoU: 0.4936
# IoU by class : [{'Backgroud': 0.9465}, {'General trash': 0.4178}, {'Paper': 0.7277}, {'Paper pack': 0.4246}, {'Metal': 0.3307}, {'Glass': 0.402}, {'Plastic': 0.321}, {'Styrofoam': 0.6479}, {'Plastic bag': 0.8156}, {'Battery': 0.0}, {'Clothing': 0.3962}]
# Epoch [55/70], Step [25/328],                         Loss: 0.1391, mIoU: 0.6104
# Epoch [55/70], Step [50/328],                         Loss: 0.1992, mIoU: 0.6127
# Epoch [55/70], Step [75/328],                         Loss: 0.1097, mIoU: 0.6242
# Epoch [55/70], Step [100/328],                         Loss: 0.3484, mIoU: 0.634
# Epoch [55/70], Step [125/328],                         Loss: 0.2209, mIoU: 0.6353
# Epoch [55/70], Step [150/328],                         Loss: 0.1312, mIoU: 0.634
# Epoch [55/70], Step [175/328],                         Loss: 0.1552, mIoU: 0.6378
# Epoch [55/70], Step [200/328],                         Loss: 0.1278, mIoU: 0.6375
# Epoch [55/70], Step [225/328],                         Loss: 0.1833, mIoU: 0.6388
# Epoch [55/70], Step [250/328],                         Loss: 0.0657, mIoU: 0.6385
# Epoch [55/70], Step [275/328],                         Loss: 0.2022, mIoU: 0.636
# Epoch [55/70], Step [300/328],                         Loss: 0.1392, mIoU: 0.6346
# Epoch [55/70], Step [325/328],                         Loss: 0.1614, mIoU: 0.6353
# Start validation #55
# Validation #55  Average Loss: 0.3606, Accuracy : 0.9131,                 mIoU: 0.4968
# IoU by class : [{'Backgroud': 0.946}, {'General trash': 0.4137}, {'Paper': 0.7129}, {'Paper pack': 0.4742}, {'Metal': 0.309}, {'Glass': 0.4614}, {'Plastic': 0.3201}, {'Styrofoam': 0.6301}, {'Plastic bag': 0.809}, {'Battery': 0.0}, {'Clothing': 0.3879}]
# Epoch [56/70], Step [25/328],                         Loss: 0.2665, mIoU: 0.6696
# Epoch [56/70], Step [50/328],                         Loss: 0.1507, mIoU: 0.6404
# Epoch [56/70], Step [75/328],                         Loss: 0.2394, mIoU: 0.6405
# Epoch [56/70], Step [100/328],                         Loss: 0.0943, mIoU: 0.6388
# Epoch [56/70], Step [125/328],                         Loss: 0.1676, mIoU: 0.6319
# Epoch [56/70], Step [150/328],                         Loss: 0.1391, mIoU: 0.6306
# Epoch [56/70], Step [175/328],                         Loss: 0.1807, mIoU: 0.6285
# Epoch [56/70], Step [200/328],                         Loss: 0.1266, mIoU: 0.6364
# Epoch [56/70], Step [225/328],                         Loss: 0.1469, mIoU: 0.6368
# Epoch [56/70], Step [250/328],                         Loss: 0.1669, mIoU: 0.6391
# Epoch [56/70], Step [275/328],                         Loss: 0.1892, mIoU: 0.6354
# Epoch [56/70], Step [300/328],                         Loss: 0.188, mIoU: 0.635
# Epoch [56/70], Step [325/328],                         Loss: 0.1437, mIoU: 0.6367
# Start validation #56
# Validation #56  Average Loss: 0.3288, Accuracy : 0.9173,                 mIoU: 0.5045
# IoU by class : [{'Backgroud': 0.9487}, {'General trash': 0.4164}, {'Paper': 0.7234}, {'Paper pack': 0.4476}, {'Metal': 0.3312}, {'Glass': 0.4497}, {'Plastic': 0.3317}, {'Styrofoam': 0.659}, {'Plastic bag': 0.8232}, {'Battery': 0.0}, {'Clothing': 0.4188}]
# Best performance at epoch: 56
# Save model in ./saved
# best model's epoch is 56
# Epoch [57/70], Step [25/328],                         Loss: 0.09, mIoU: 0.5802
# Epoch [57/70], Step [50/328],                         Loss: 0.1989, mIoU: 0.6102
# Epoch [57/70], Step [75/328],                         Loss: 0.1726, mIoU: 0.6124
# Epoch [57/70], Step [100/328],                         Loss: 0.0774, mIoU: 0.626
# Epoch [57/70], Step [125/328],                         Loss: 0.182, mIoU: 0.6256
# Epoch [57/70], Step [150/328],                         Loss: 0.1753, mIoU: 0.6242
# Epoch [57/70], Step [175/328],                         Loss: 0.0795, mIoU: 0.6229
# Epoch [57/70], Step [200/328],                         Loss: 0.2562, mIoU: 0.6253
# Epoch [57/70], Step [225/328],                         Loss: 0.2629, mIoU: 0.626
# Epoch [57/70], Step [250/328],                         Loss: 0.1382, mIoU: 0.6304
# Epoch [57/70], Step [275/328],                         Loss: 0.2474, mIoU: 0.6308
# Epoch [57/70], Step [300/328],                         Loss: 0.2535, mIoU: 0.6328
# Epoch [57/70], Step [325/328],                         Loss: 0.0796, mIoU: 0.6346
# Start validation #57
# Validation #57  Average Loss: 0.333, Accuracy : 0.9156,                 mIoU: 0.511
# IoU by class : [{'Backgroud': 0.9499}, {'General trash': 0.392}, {'Paper': 0.72}, {'Paper pack': 0.4905}, {'Metal': 0.3458}, {'Glass': 0.4878}, {'Plastic': 0.3689}, {'Styrofoam': 0.6594}, {'Plastic bag': 0.7994}, {'Battery': 0.0}, {'Clothing': 0.4076}]
# Best performance at epoch: 57
# Save model in ./saved
# best model's epoch is 57
# Epoch [58/70], Step [25/328],                         Loss: 0.169, mIoU: 0.6158
# Epoch [58/70], Step [50/328],                         Loss: 0.126, mIoU: 0.6405
# Epoch [58/70], Step [75/328],                         Loss: 0.2191, mIoU: 0.6337
# Epoch [58/70], Step [100/328],                         Loss: 0.1628, mIoU: 0.6372
# Epoch [58/70], Step [125/328],                         Loss: 0.1857, mIoU: 0.6406
# Epoch [58/70], Step [150/328],                         Loss: 0.1803, mIoU: 0.6436
# Epoch [58/70], Step [175/328],                         Loss: 0.2005, mIoU: 0.6514
# Epoch [58/70], Step [200/328],                         Loss: 0.1479, mIoU: 0.6499
# Epoch [58/70], Step [225/328],                         Loss: 0.2152, mIoU: 0.6525
# Epoch [58/70], Step [250/328],                         Loss: 0.1392, mIoU: 0.651
# Epoch [58/70], Step [275/328],                         Loss: 0.1838, mIoU: 0.6492
# Epoch [58/70], Step [300/328],                         Loss: 0.2217, mIoU: 0.6514
# Epoch [58/70], Step [325/328],                         Loss: 0.1439, mIoU: 0.6527
# Start validation #58
# Validation #58  Average Loss: 0.3409, Accuracy : 0.9154,                 mIoU: 0.5044
# IoU by class : [{'Backgroud': 0.9472}, {'General trash': 0.4083}, {'Paper': 0.719}, {'Paper pack': 0.5174}, {'Metal': 0.3514}, {'Glass': 0.3863}, {'Plastic': 0.3363}, {'Styrofoam': 0.678}, {'Plastic bag': 0.8065}, {'Battery': 0.0}, {'Clothing': 0.3982}]
# Epoch [59/70], Step [25/328],                         Loss: 0.1723, mIoU: 0.5841
# Epoch [59/70], Step [50/328],                         Loss: 0.1882, mIoU: 0.6362
# Epoch [59/70], Step [75/328],                         Loss: 0.1443, mIoU: 0.6486
# Epoch [59/70], Step [100/328],                         Loss: 0.1228, mIoU: 0.6494
# Epoch [59/70], Step [125/328],                         Loss: 0.1254, mIoU: 0.6492
# Epoch [59/70], Step [150/328],                         Loss: 0.1873, mIoU: 0.6381
# Epoch [59/70], Step [175/328],                         Loss: 0.2169, mIoU: 0.6344
# Epoch [59/70], Step [200/328],                         Loss: 0.1904, mIoU: 0.6399
# Epoch [59/70], Step [225/328],                         Loss: 0.1476, mIoU: 0.6406
# Epoch [59/70], Step [250/328],                         Loss: 0.1918, mIoU: 0.6423
# Epoch [59/70], Step [275/328],                         Loss: 0.2254, mIoU: 0.6407
# Epoch [59/70], Step [300/328],                         Loss: 0.3675, mIoU: 0.6422

# %% [markdown]
# ## 저장된 model 불러오기 (학습된 이후)

# %%
# best model 저장된 경로
model_path = './saved/augall-griddropout_efficient_unet_best_model.pt'

# best model 불러오기
checkpoint = torch.load(model_path, map_location=device)
state_dict = checkpoint.state_dict()
model.load_state_dict(state_dict)

model = model.to(device)
# 추론을 실행하기 전에는 반드시 설정 (batch normalization, dropout 를 평가 모드로 설정)
# model.eval()

# %% [markdown]
# ### `plot_examples()` 시각화 함수 정의

# %%
def plot_examples(mode="train", batch_id=0, num_examples=batch_size, dataloaer=train_loader):
    """Visualization of images and masks according to batch size
    Args:
        mode: train/val/test (str)
        batch_id : 0 (int) 
        num_examples : 1 ~ batch_size(e.g. 8) (int)
        dataloaer : data_loader (dataloader) 
    Returns:
        None
    """
    # variable for legend
    category_and_rgb = [[category, (r,g,b)] for idx, (category, r, g, b) in enumerate(class_colormap.values)]
    legend_elements = [Patch(facecolor=webcolors.rgb_to_hex(rgb), 
                             edgecolor=webcolors.rgb_to_hex(rgb), 
                             label=category) for category, rgb in category_and_rgb]
    
    # test / validation set에 대한 시각화
    if (mode in ('train', 'val')):
        with torch.no_grad():
            for index, (imgs, masks, image_infos) in enumerate(dataloaer):
                if index == batch_id:
                    image_infos = image_infos
                    temp_images = imgs
                    temp_masks = masks

                    model.eval()
                    # inference
                    outs = model(torch.stack(temp_images).to(device))
                    oms = torch.argmax(outs, dim=1).detach().cpu().numpy()

                    break
                else:
                    continue
    
        fig, ax = plt.subplots(nrows=num_examples, ncols=3, figsize=(12, 4*num_examples), constrained_layout=True)
        fig.tight_layout()
        for row_num in range(num_examples):
            # Original Image
            ax[row_num][0].imshow(temp_images[row_num].permute([1,2,0]))
            ax[row_num][0].set_title(f"Orignal Image : {image_infos[row_num]['file_name']}")
            # Groud Truth
            ax[row_num][1].imshow(label_to_color_image(masks[row_num].detach().cpu().numpy()))
            ax[row_num][1].set_title(f"Groud Truth : {image_infos[row_num]['file_name']}")
            # Pred Mask
            ax[row_num][2].imshow(label_to_color_image(oms[row_num]))
            ax[row_num][2].set_title(f"Pred Mask : {image_infos[row_num]['file_name']}")
            ax[row_num][2].legend(handles=legend_elements, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
        plt.show()
    
    # test set에 대한 시각화
    else :
        with torch.no_grad():
            for index, (imgs, image_infos) in enumerate(dataloaer):
                if index == batch_id:
                    image_infos = image_infos
                    temp_images = imgs

                    model.eval()
                    
                    # inference
                    outs = model(torch.stack(temp_images).to(device))['out']
                    oms = torch.argmax(outs, dim=1).detach().cpu().numpy()
                    break
                else:
                    continue
    
        fig, ax = plt.subplots(nrows=num_examples, ncols=2, figsize=(10, 4*num_examples), constrained_layout=True)

        for row_num in range(num_examples):
            # Original Image
            ax[row_num][0].imshow(temp_images[row_num].permute([1,2,0]))
            ax[row_num][0].set_title(f"Orignal Image : {image_infos[row_num]['file_name']}")
            # Pred Mask
            ax[row_num][1].imshow(label_to_color_image(oms[row_num]))
            ax[row_num][1].set_title(f"Pred Mask : {image_infos[row_num]['file_name']}")
            ax[row_num][1].legend(handles=legend_elements, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
            
        plt.show()

# %% [markdown]
# #### train set 시각화

# %%
plot_examples(mode="train", batch_id=7, num_examples=batch_size, dataloaer=train_loader)

# %% [markdown]
# #### validation set 시각화

# %%
plot_examples(mode="val", batch_id=0, num_examples=batch_size, dataloaer=val_loader)

# %% [markdown]
# #### test set 시각화

# %%
# plot_examples(mode="test", batch_id=0, num_examples=batch_size, dataloaer=test_loader)

# %% [markdown]
# ## submission을 위한 test 함수 정의

# %%
def test(model, data_loader, device):
    size = 256
    transform = A.Compose([A.Resize(size, size)])
    print('Start prediction.')
    
    model.eval()
    
    file_name_list = []
    preds_array = np.empty((0, size*size), dtype=np.long)
    
    with torch.no_grad():
        for step, (imgs, image_infos) in enumerate(tqdm(test_loader)):
            
            # inference (512 x 512)
            outs = model(torch.stack(imgs).to(device))
            oms = torch.argmax(outs.squeeze(), dim=1).detach().cpu().numpy()
            
            # resize (256 x 256)
            temp_mask = []
            for img, mask in zip(np.stack(imgs), oms):
                transformed = transform(image=img, mask=mask)
                mask = transformed['mask']
                temp_mask.append(mask)
                
            oms = np.array(temp_mask)
            
            oms = oms.reshape([oms.shape[0], size*size]).astype(int)
            preds_array = np.vstack((preds_array, oms))
            
            file_name_list.append([i['file_name'] for i in image_infos])
    print("End prediction.")
    file_names = [y for x in file_name_list for y in x]
    
    return file_names, preds_array

# %% [markdown]
# ## submission.csv 생성

# %%
# sample_submisson.csv 열기
submission = pd.read_csv('./submission/sample_submission.csv', index_col=None)

# test set에 대한 prediction
file_names, preds = test(model, test_loader, device)

# PredictionString 대입
for file_name, string in zip(file_names, preds):
    submission = submission.append({"image_id" : file_name, "PredictionString" : ' '.join(str(e) for e in string.tolist())}, 
                                   ignore_index=True)

# submission.csv로 저장
submission.to_csv("./submission/augall-griddropout_efficient_unet_best_model.csv", index=False)
